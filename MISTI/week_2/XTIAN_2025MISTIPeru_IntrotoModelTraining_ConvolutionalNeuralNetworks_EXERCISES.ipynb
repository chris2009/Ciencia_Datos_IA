# %% [markdown]
# **If you haven't already, please hit :**
#
# `File` -> `Save a Copy in Drive`
#
# **to copy this notebook to your Google drive, and work on a copy. If you don't do this, your changes won't be saved!**

# %% [markdown]
# # Model Training with Convolutional Neural Networks using MNIST

# %%
# @title
# ==============================================
# 0. Module imports
# ==============================================

import torch
from torch import nn, optim
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
import torchvision
from torchvision import datasets, transforms

# data manipulation
import pandas as pd
import numpy as np
import scipy.stats as st
import scipy

# plots
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
import pylab as pl

# classification algorithms
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.preprocessing import StandardScaler

# dimension reduction
from sklearn.decomposition import PCA

# cross-validation
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_predict
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn import model_selection

# parallel processing
from joblib import Parallel, delayed
import multiprocessing

# model evaluation
from sklearn.metrics import roc_auc_score
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import confusion_matrix, classification_report

import warnings
warnings.filterwarnings("ignore")

import seaborn as sns

device = "cpu"

# %% [markdown]
# Some visualization code. No need to understand this cell, but don't forget to run it!

# %%
# @title
from graphviz import Digraph

HAPPY_COLORS_PALETTE = ["#01BEFE", "#FFDD00", "#FF7D00", "#FF006D", "#93D30C", "#8F00FF"]
def visualize(model):
    hidden_layers = []
    output_layer = 0
    layers = [layer for layer in model.modules() if type(layer) == torch.nn.Linear]

    # custom script to get all the shapes of a network's layers
    sizes = list()
    state_dict = net.state_dict()
    for idx, key in enumerate(state_dict.keys()):
      if key.endswith('weight'):
        output_size, input_size = state_dict[key].shape
        if idx == 0:
          sizes.append(input_size)
        sizes.append(output_size)

    input_layer = sizes[0]
    for layer in layers:
        if layer == layers[0]:
            hidden_layers.append(layer.out_features)

        else:
            if layer == layers[-1]:
                output_layer = layer.out_features
            else:
                hidden_layers.append(layer.out_features)

        last_layer_nodes = input_layer
        nodes_up = input_layer

    g = Digraph("g", filename='visualization_tmp')
    n = 0
    g.graph_attr.update(splines="false", nodesep="0.5", ranksep="0", rankdir='LR')
    # Input Layer
    with g.subgraph(name="cluster_input") as c:
          c.attr(color="white")
          for i in range(0, sizes[0]):
              n += 1
              c.node(str(n))
              c.attr(labeljust="1")
              c.attr(label="Input Layer", labelloc="bottom")
              c.attr(rank="same")
              c.node_attr.update(
                  width="0.65",
                  style="filled",
                  shape="circle",
                  color=HAPPY_COLORS_PALETTE[3],
                  fontcolor=HAPPY_COLORS_PALETTE[3],
              )
    for layer_idx in range(0, len(sizes) - 2):
        with g.subgraph(name="cluster_" + str(layer_idx + 1)) as c:
            c.attr(color="white")
            c.attr(rank="same")
            label = f'Hidden Layer {layer_idx + 1}'
            c.attr(labeljust="right", labelloc="b", label=label)
            for j in range(0, hidden_layers[layer_idx]):
                n += 1
                c.node(
                    str(n),
                    width="0.65",
                    shape="circle",
                    style="filled",
                    color=HAPPY_COLORS_PALETTE[0],
                    fontcolor=HAPPY_COLORS_PALETTE[0],
                )
                for h in range(nodes_up - last_layer_nodes + 1, nodes_up + 1):
                    g.edge(str(h), str(n))
            last_layer_nodes = hidden_layers[layer_idx]
            nodes_up += hidden_layers[layer_idx]

    with g.subgraph(name="cluster_output") as c:
        c.attr(color="white")
        c.attr(rank="same")
        c.attr(labeljust="1")
        for i in range(1, output_layer + 1):
            n += 1
            c.node(
                str(n),
                width="0.65",
                shape="circle",
                style="filled",
                color=HAPPY_COLORS_PALETTE[4],
                fontcolor=HAPPY_COLORS_PALETTE[4],

            )
            for h in range(nodes_up - last_layer_nodes + 1, nodes_up + 1):
                g.edge(str(h), str(n))
        c.attr(label="Output Layer", labelloc="bottom")
        c.node_attr.update(
            color="#2ecc71", style="filled", fontcolor="#2ecc71", shape="circle"
        )

    g.attr(arrowShape="none")
    g.edge_attr.update(arrowhead="none", color="#707070", penwidth="2")
    g.view()
    return g

# %% [markdown]
# ## Define DataLoaders
#
# This code creates **data loaders** for the **MNIST dataset** using PyTorch, which handles the loading and batching of training and testing data. The **batch sizes** are set to 64 for training and 1000 for testing to balance computation efficiency and memory usage. The `train_loader` shuffles the training data for better generalization, while the `test_loader` keeps the test data in a fixed order.
#
# Both data loaders apply a series of **transformations** to the images: converting them to tensors and normalizing pixel values to have a mean of 0.1307 and a standard deviation of 0.3081. These normalization values are calculated based on the MNIST dataset and help improve model convergence during training.

# %%
# Define the Batch Sizes
batch_size_train = 64
batch_size_test = 1000

# Training DataLoader
train_loader = torch.utils.data.DataLoader(
  torchvision.datasets.MNIST('sample_data/', train=True, download=True,
                             transform=torchvision.transforms.Compose([
                               torchvision.transforms.ToTensor(),
                               torchvision.transforms.Normalize(
                                 (0.1307,), (0.3081,))
                             ])),
  batch_size=batch_size_train, shuffle=True)

# Testing DataLoader
test_loader = torch.utils.data.DataLoader(
  torchvision.datasets.MNIST('sample_data/', train=False, download=True,
                             transform=torchvision.transforms.Compose([
                               torchvision.transforms.ToTensor(),
                               torchvision.transforms.Normalize(
                                 (0.1307,), (0.3081,))
                             ])),
  batch_size=batch_size_test, shuffle=False)

# %% [markdown]
# ### ANALYZE: Explore Common Neural Network Layers
#
# In this exercise, we explore common PyTorch layers and use them to transform an example MNIST image.
#
# Tasks:
# 1. Explore `nn.Flatten()` - Converts a multi-dimensional tensor into a single-dimensional array.
# 2. Explore `nn.Linear()`– Applies a linear transformation to the input.
# 3. Explore `nn.ReLU()`– Introduces non-linearity to the network.
# 4. Explore `nn.Sequential()`– Combines layers into a sequence.
# 5. Explore `nn.Softmax()`Converts raw scores (logits) into probabilities.

# %%
data_iter = iter(train_loader)
images, labels = next(data_iter)
input_image = images[0]
print(input_image.size())
# Out:
# torch.Size([1, 28, 28])

# %% [markdown]
# #### TASK 1: nn.Flatten
#
# The `nn.Flatten()` layer reshapes a 2D image into a 1D array of pixel values. This is often the first step when using fully connected layers, as they require a flat input.

# %%
flatten = nn.Flatten()
flat_image = flatten(input_image)
print(flat_image.size())

fig, ax = plt.subplots(1, 2, figsize=(12, 6))

# Original image
ax[0].imshow(input_image.squeeze(), cmap='gray')
ax[0].set_title(f'Original Image - Label: {labels[0].item()}')
ax[0].axis('off')

# Plot the flattened Image
ax[1].imshow(flat_image.detach().numpy(), cmap='gray', aspect='auto')
ax[1].set_title('Flattened Image (784 pixels)')
ax[1].set_xlabel('Pixel Index')
ax[1].set_ylabel('Pixel Value')

sns.despine()

plt.tight_layout()
plt.show()
# Out:
# torch.Size([1, 784])

# %% [markdown]
# #### TASK 2: nn.Linear
#
# The `nn.Linear()` layer applies a linear transformation to the input data using its weights and biases. This helps the network create a feature space.

# %%
layer1 = nn.Linear(in_features=28*28, out_features=20)
hidden1 = layer1(flat_image)
print(hidden1.size())

fig, ax = plt.subplots(1, 2, figsize=(12, 6))

# Original image
ax[0].imshow(input_image.squeeze(), cmap='gray')
ax[0].set_title(f'Original Image - Label: {labels[0].item()}')
ax[0].axis('off')

# Hidden layer output as a bar chart
ax[1].bar(range(hidden1.size(1)), hidden1.detach().numpy().squeeze())
ax[1].set_title('Hidden Layer Output (20 features)')
ax[1].set_xlabel('Feature Index')
ax[1].set_ylabel('Feature Value')

sns.despine()

plt.tight_layout()
plt.show()
# Out:
# torch.Size([1, 20])

# %% [markdown]
# #### TASK 3: nn.ReLU
#
# The `nn.ReLU()` activation function introduces non-linearity into the model. Without non-linear functions, the network would be limited to learning only linear relationships.

# %%
hidden1_ReLU = nn.ReLU()(hidden1)

fig, ax = plt.subplots(1, 2, figsize=(12, 6), sharey = True)

# Original image
ax[0].bar(range(hidden1.size(1)), hidden1.detach().numpy().squeeze())
ax[0].set_title(f'Original Image - Label: {labels[0].item()}')

# Hidden layer output as a bar chart after ReLU
ax[1].bar(range(hidden1_ReLU.size(1)), hidden1_ReLU.detach().numpy().squeeze())
ax[1].set_title('Hidden Layer Output (ReLU Applied, 20 Features)')
ax[1].set_xlabel('Feature Index')
ax[1].set_ylabel('Feature Value')

sns.despine()

plt.tight_layout()
plt.show()

# %% [markdown]
# #### TASK 4: nn.Sequential
#
# The `nn.Sequential()` module allows us to define a complete network by chaining multiple layers together. This creates a straightforward, ordered flow of data through the network.

# %%
seq_modules = nn.Sequential(
    flatten,
    layer1,
    nn.ReLU(),
    nn.Linear(20, 10)
)
logits = seq_modules(input_image)

# Capture outputs at each step
flattened = flatten(input_image)
layer1_output = layer1(flattened)
relu_output = nn.ReLU()(layer1_output)
logits = seq_modules(input_image)

# Plot the outputs
fig, axes = plt.subplots(1, 4, figsize=(15, 4))

axes[0].imshow(input_image.squeeze().numpy(), cmap='gray')
axes[0].set_title("Original Image")

axes[1].imshow(flattened.detach().numpy(), cmap='gray', aspect='auto')
axes[1].set_title("Flattened")

axes[2].bar(range(20), layer1_output.detach().numpy().squeeze())
axes[2].set_title("Layer 1 Output")

axes[3].bar(range(10), logits.detach().numpy().squeeze())
axes[3].set_title("Logits (Output)")

sns.despine()

plt.tight_layout()
plt.show()

# %% [markdown]
# #### TASK 5: nn.Softmax
#
# The `nn.Softmax()` layer converts raw logits into probabilities that sum to 1. It’s typically applied to the final layer of a classification network to produce class probabilities.

# %%
# Apply Softmax to convert logits to probabilities
softmax = nn.Softmax(dim=1)
pred_probab = softmax(logits)

# Plot the logits and the resulting probabilities
fig, axes = plt.subplots(1, 2, figsize=(12, 4))

# Logits (Before Softmax)
axes[0].bar(range(10), logits.squeeze().detach().numpy())
axes[0].set_title("Logits (Before Softmax)")
axes[0].set_xlabel("Class Index")
axes[0].set_ylabel("Value")

# Predicted Probabilities (After Softmax)
axes[1].bar(range(10), pred_probab.squeeze().detach().numpy())
axes[1].set_title("Predicted Probabilities (After Softmax)")
axes[1].set_xlabel("Class Index")
axes[1].set_ylabel("Probability")

sns.despine()

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Training a Simple Convolutional Network
#
# The `train()` function is responsible for updating the network's parameters during the **training phase** using data from the training set. It sets the network to **training mode**, enabling layers like dropout that improve generalization. For **fully connected networks**, the input data is flattened into a 1D vector before being passed to the network, but this step is **skipped for convolutional neural networks (CNNs)**, which handle multi-dimensional inputs directly. During each batch, the function performs a **forward pass** to make predictions, calculates the **loss** using the Negative Log Likelihood function, and performs **backpropagation** to update the network’s weights. The function tracks and logs the **training progress** to monitor performance over time.

# %%
# Note: network.train() puts the network into "nondeterministic mode".
# This doesn't matter for the fully connected network, but it will matter for convolutional networks.
# CNNs rely on preserving spatial structure, so the nondeterministic mode can impact results.
def train(network, optimizer, epoch, trainloader, flatten_data=True):

    network.train()  # Set the network to training mode
    loss_logs = list()  # Track the loss over time

    for batch_idx, (data, target) in enumerate(trainloader):
        # For fully connected networks, we flatten the image data to feed it into the network.
        # CNNs, however, expect multi-dimensional image inputs, so we skip flattening.
        if flatten_data:
            data = flatten(data)  # Flatten the image (only for fully connected networks)

        # Move data to GPU if available
        data, target = data.to(device), target.to(device)

        # Zero the gradients from the previous batch
        optimizer.zero_grad()

        # Perform the forward pass through the network
        output = network(data)

        # Compute the loss using the Negative Log Likelihood loss function
        # This loss function is often used for classification tasks with multiple classes.
        loss = F.nll_loss(output, target)

        # Backpropagation: Calculate the gradients of the loss with respect to the network's parameters
        loss.backward()

        # Perform the optimization step: Update the network's parameters
        optimizer.step()

        # Print training progress at regular intervals
        if batch_idx % log_interval == 0:
            examples_shown = batch_idx * len(data)
            total_examples = len(trainloader.dataset)
            fraction_shown = round(examples_shown / total_examples * 100.0, 2)
            rounded_loss = round(loss.item(), 4)
            print(f'Train Epoch {epoch} Progress: {fraction_shown}%\tLoss: {rounded_loss}')

            examples_so_far = batch_idx * len(data) + epoch * len(trainloader.dataset)
            loss_logs.append((examples_so_far, loss.item()))

    return loss_logs

# %% [markdown]
# This `test()` function evaluates the performance of a trained neural network on unseen data from the test set. It puts the network into **evaluation mode** to ensure consistent behavior by disabling layers like dropout, which are only active during training. The function then loops through the test data, performs a **forward pass** to generate predictions, and calculates both the **average loss** and **accuracy**. For fully connected networks, the input data must be **flattened into a 1D vector** before being passed to the network, but this step is unnecessary for **convolutional neural networks (CNNs)**, which process multi-dimensional image data directly. The function finally prints the results, helping us assess how well the model generalizes to new data.

# %%
def test(network, flatten_data=True):
    # Set the network to evaluation mode.
    # This disables certain behaviors like dropout that are only used during training.
    network.eval()

    # Initialize test loss and correct predictions counters
    test_loss = 0
    correct = 0

    # Disable gradient calculation for efficiency since we are only testing the model.
    with torch.no_grad():
        for data, target in test_loader:
            # For fully connected networks, flatten the image data into a 1D vector.
            # CNNs expect multi-dimensional image inputs, so flattening is unnecessary for them.
            if flatten_data:
                data = flatten(data)

            # Move data and target to the GPU if available
            data, target = data.to(device), target.to(device)

            # Perform a forward pass through the network
            output = network(data)

            # Calculate the cumulative test loss using Negative Log Likelihood loss
            test_loss += F.nll_loss(output, target, size_average=False).item()

            # Get the predicted class for each input sample
            pred = output.data.max(1, keepdim=True)[1]

            # Count the number of correct predictions
            correct += pred.eq(target.data.view_as(pred)).sum()

    # Calculate the average test loss by dividing by the number of samples
    test_loss /= len(test_loader.dataset)

    # Calculate the test accuracy as a percentage
    accuracy = round(100. * correct.item() / len(test_loader.dataset), 2)

    # Print the test loss and accuracy
    print(f'\nTest set: Avg loss {round(test_loss, 4)}, Accuracy {accuracy}%\n')

    # Return the test loss and accuracy for logging purposes
    return test_loss, accuracy

# %% [markdown]
# ### EXERCISE: Define a Convolutional Neural Network
#
# Tasks:
# 1. Define a convolutional network with the following architecture.
#
#   - Define the CNN layers.
#
#     A. Replace `<REPLACE ME AND MY ARROWS>` with the correct code to define the second convolutional layer using `nn.Conv2d()`.
#       - Input channels = 1 (grayscale image)
#       - Output channels = 10
#       - Kernel size = 5
#
#     B. Replace `<REPLACE ME AND MY ARROWS>` with the correct code to define the second convolutional layer using `nn.Conv2d()`.
#       - Input channels = 10 (from the previous layer's output)
#       - Output channels = 20
#       - Kernel size = 5
#
#     C. Replace `<REPLACE ME AND MY ARROWS>` with the correct code to add a dropout layer using `nn.Dropout2d()`.
#
#     D. Replace `<REPLACE ME AND MY ARROWS>` with the correct code to define the first fully connected layer using `nn.Linear()`.
#       - Input features = 320 (flattened feature maps)
#       - Output features = 50
#
#     E. Replace `<REPLACE ME AND MY ARROWS>` with the correct code to define the second fully connected layer using `nn.Linear()`.
#       - Input features = 50 (from the previous fully connected layer)
#       - Output features = 10 (number of classes)
#
#   - Define the forward pass of the CNN.
#
#     F. Replace `<REPLACE ME AND MY ARROWS>` with the correct code to apply the first convolutional layer followed by ReLU activation and 2x2 max pooling.
#
#     G. Replace `<REPLACE ME AND MY ARROWS>` with the correct code to apply the second convolutional layer followed by a dropout layer.
#
#     H. Replace `<REPLACE ME AND MY ARROWS>` with the correct code to apply 2x2 max pooling to the output of the second convolutional layer.
#
#     I. Replace `<REPLACE ME AND MY ARROWS>` with the correct code to apply a ReLU activation to introduce non-linearity
#
#     J. Replace `<REPLACE ME AND MY ARROWS>` with the correct code to apply a fully connected layer with a ReLU activation.
#
#     K. Replace `<REPLACE ME AND MY ARROWS>` with the correct code to apply a fully connected layer.

# %%
# TASK 1 EXERCISE

# Define the convolutional neural network (CNN) architecture
class ConvNet(nn.Module):

    def __init__(self):
        super(ConvNet, self).__init__()

        # First convolutional layer:
        # - 1 input channel (grayscale image)
        # - 10 output channels (feature maps)
        # - 5x5 kernel size (learns 5x5 filters to detect patterns)
        self.conv1 = nn.Conv2d(in_channels=1, out_channels=10, kernel_size=5) # QUESTION A

        # Second convolutional layer:
        # - Takes 10 input feature maps from conv1
        # - Produces 20 output feature maps
        # - 5x5 kernel size
        self.conv2 =  nn.Conv2d(in_channels=10, out_channels=20, kernel_size=5) # QUESTION B

        # Dropout layer to reduce overfitting by randomly dropping units during training
        self.conv2_drop = nn.Dropout2d() # QUESTION C

        # First fully connected layer:
        # - 320 input features (flattened feature maps after convolutions)
        # - 50 output features (reduces dimensionality for classification)
        self.fc1 = nn.Linear(in_features=320, out_features=50) # QUESTION D

        # Second fully connected layer:
        # - 50 input features from the previous layer
        # - 10 output features corresponding to the number of classes
        self.fc2 = nn.Linear(in_features=50, out_features=10) # QUESTION E

    def forward(self, x):
        # First convolutional layer followed by:
        # - ReLU activation (introduces non-linearity)
        # - Max pooling (reduces dimensionality by taking the max value from 2x2 regions)
        x = F.max_pool2d(F.relu(self.conv1(x)), 2) # QUESTION F

        # Second convolutional layer followed by dropout:
        # - Helps reduce overfitting by randomly dropping out units
        x = self.conv2_drop(self.conv2(x)) # QUESTION G

        # Apply max pooling to reduce the feature map size
        # - Uses a 2x2 pooling region
        x = F.max_pool2d(x, 2) # QUESTION H

        # Apply ReLU activation to introduce non-linearity
        x = F.relu(x) # QUESTION I

        # Flatten the output to a 1D vector before passing it to fully connected layers
        # - The input size is reshaped to (-1, 320), where -1 infers the batch size
        x = x.view(-1, 320)

        # Apply the first fully connected layer followed by ReLU activation
        x = F.relu(self.fc1(x)) # QUESTION J

        # Apply dropout to the fully connected layer's output to reduce overfitting
        # - Dropout is only applied during training
        x = F.dropout(x, training=self.training)

        # Apply the second fully connected layer (output layer)
        # - Produces 10 output values corresponding to class scores
        x = self.fc2(x) # QUESTION K

        # Return the log of softmax probabilities for classification
        # - Converts the output scores into a categorical probability distribution
        return F.log_softmax(x)

# %% [markdown]
# ### EXERCISE: Train a Convolutional Neural Network with MNIST
#
# Tasks:
# 1. Set Up Your Environment and Define the Network
#   - Define key hyperparameters to control the training process.
#   - Create an instance of your CNN model using `ConvNet()`.
#   - Move the model to the appropriate device (CPU/GPU).
#   - Configure the optimizer using `optim.SGD()`.
# 2. Train Your CNN Model.
#   - Train your model for the specified number of epochs using the `train()` function.
# 3. Evaluate and Visualize the Model’s Performance.
#   - Use the `plot_results()` function to visualize:
#     - Training Loss and Test Loss Over Time
#     - Test Accuracy Over Epochs
#     - Analyze the plots to assess your model's performance.

# %% [markdown]
# #### TASK 1: Prepare your Environment to Train your CNN

# %%
# TASK 1 EXERCISE

# Define hyperparameters
# Hyperparameters control the behavior of the training process.

learning_rate = 0.01  # Controls how large the weight updates are during training.
# A smaller learning rate leads to slower but more stable convergence.
# A larger learning rate can speed up convergence but may cause instability.

momentum = 0.9
# Momentum helps accelerate convergence by adding a fraction of the previous update to the current update.
# This helps the model avoid getting stuck in local minima and smooths the optimization process.

n_epochs = 2
# Number of complete passes through the training dataset during training.
# Increasing the number of epochs can improve performance, but may lead to overfitting if too high.

log_interval = 10
# How often (in batches) we print the training progress.
# For example, a log_interval of 10 means the network will print updates every 10 batches.

# Initialize the convolutional network
conv_network = ConvNet()

# Move the network to the GPU if available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
conv_network = conv_network.to(device)

# Define the optimizer
conv_optimizer = optim.SGD(
    conv_network.parameters(),
    lr=learning_rate,
    momentum=momentum
)

# %% [markdown]
# #### TASK 2: Train your Model

# %%
# TASK 2 EXERCISE

# Initialize lists to track test accuracy, test losses, and training losses
test_accuracies, test_losses, train_losses = list(), list(), list()
total_examples_seen = 0  # Tracks the total number of examples processed during training

# Training loop over the specified number of epochs
for epoch in range(n_epochs):

    # Run the test phase before training each epoch to log initial performance
    test_loss, test_accuracy = test(conv_network, flatten_data=False)

    # Train the network on the training dataset for the current epoch
    train_loss_logs = train(
      conv_network,
      conv_optimizer,
      epoch,
      train_loader,
      flatten_data=False
    )

    # Log test performance
    test_accuracies.append((epoch, test_accuracy))  # Log accuracy for this epoch
    test_losses.append((total_examples_seen, test_loss))  # Log test loss

    # Log training losses
    train_losses.extend(train_loss_logs)

    # Update the total number of examples seen
    total_examples_seen = train_loss_logs[-1][0]

# Final test phase after completing all epochs
test_loss, test_accuracy = test(conv_network, flatten_data=False)
test_accuracies.append((n_epochs, test_accuracy))
test_losses.append((total_examples_seen, test_loss))

# At the end of the training process, we have:
# - test_accuracies: A list tracking the model's accuracy on the test set after each epoch.
# - test_losses: A list tracking the test loss after each epoch.
# - train_losses: A detailed log of the training loss over time.
# Out:
# Test set: Avg loss 2.312, Accuracy 9.22%
#
# Train Epoch 0 Progress: 0.0%	Loss: 2.311
# Train Epoch 0 Progress: 1.07%	Loss: 2.2813
# Train Epoch 0 Progress: 2.13%	Loss: 2.2184
# Train Epoch 0 Progress: 3.2%	Loss: 2.1649
# Train Epoch 0 Progress: 4.27%	Loss: 1.797
# Train Epoch 0 Progress: 5.33%	Loss: 1.4525
# Train Epoch 0 Progress: 6.4%	Loss: 1.1763
# Train Epoch 0 Progress: 7.47%	Loss: 0.9683
# Train Epoch 0 Progress: 8.53%	Loss: 0.9845
# Train Epoch 0 Progress: 9.6%	Loss: 1.0096
# Train Epoch 0 Progress: 10.67%	Loss: 0.7093
# Train Epoch 0 Progress: 11.73%	Loss: 0.834
# Train Epoch 0 Progress: 12.8%	Loss: 0.587
# Train Epoch 0 Progress: 13.87%	Loss: 0.6845
# Train Epoch 0 Progress: 14.93%	Loss: 0.6044
# Train Epoch 0 Progress: 16.0%	Loss: 0.6235
# Train Epoch 0 Progress: 17.07%	Loss: 0.7207
# Train Epoch 0 Progress: 18.13%	Loss: 0.3951
# Train Epoch 0 Progress: 19.2%	Loss: 0.8963
# Train Epoch 0 Progress: 20.27%	Loss: 0.7556
# Train Epoch 0 Progress: 21.33%	Loss: 0.5412
# Train Epoch 0 Progress: 22.4%	Loss: 0.7357
# Train Epoch 0 Progress: 23.47%	Loss: 0.5524
# Train Epoch 0 Progress: 24.53%	Loss: 0.7085
# Train Epoch 0 Progress: 25.6%	Loss: 0.69
# Train Epoch 0 Progress: 26.67%	Loss: 0.5134
# Train Epoch 0 Progress: 27.73%	Loss: 0.5522
# Train Epoch 0 Progress: 28.8%	Loss: 0.5662
# Train Epoch 0 Progress: 29.87%	Loss: 0.511
# Train Epoch 0 Progress: 30.93%	Loss: 0.7816
# Train Epoch 0 Progress: 32.0%	Loss: 0.6119
# Train Epoch 0 Progress: 33.07%	Loss: 0.5118
# Train Epoch 0 Progress: 34.13%	Loss: 0.5184
# Train Epoch 0 Progress: 35.2%	Loss: 0.4415
# Train Epoch 0 Progress: 36.27%	Loss: 0.4001
# Train Epoch 0 Progress: 37.33%	Loss: 0.7091
# Train Epoch 0 Progress: 38.4%	Loss: 0.4575
# Train Epoch 0 Progress: 39.47%	Loss: 0.2567
# Train Epoch 0 Progress: 40.53%	Loss: 0.4015
# Train Epoch 0 Progress: 41.6%	Loss: 0.5755
# Train Epoch 0 Progress: 42.67%	Loss: 0.4408
# Train Epoch 0 Progress: 43.73%	Loss: 0.5221
# Train Epoch 0 Progress: 44.8%	Loss: 0.5883
# Train Epoch 0 Progress: 45.87%	Loss: 0.4457
# Train Epoch 0 Progress: 46.93%	Loss: 0.337
# Train Epoch 0 Progress: 48.0%	Loss: 0.3093
# Train Epoch 0 Progress: 49.07%	Loss: 0.3551
# Train Epoch 0 Progress: 50.13%	Loss: 0.2428
# Train Epoch 0 Progress: 51.2%	Loss: 0.3105
# Train Epoch 0 Progress: 52.27%	Loss: 0.4448
# Train Epoch 0 Progress: 53.33%	Loss: 0.423
# Train Epoch 0 Progress: 54.4%	Loss: 0.2942
# Train Epoch 0 Progress: 55.47%	Loss: 0.2553
# Train Epoch 0 Progress: 56.53%	Loss: 0.3804
# Train Epoch 0 Progress: 57.6%	Loss: 0.4517
# Train Epoch 0 Progress: 58.67%	Loss: 0.2494
# Train Epoch 0 Progress: 59.73%	Loss: 0.3907
# Train Epoch 0 Progress: 60.8%	Loss: 0.325
# Train Epoch 0 Progress: 61.87%	Loss: 0.2461
# Train Epoch 0 Progress: 62.93%	Loss: 0.1242
# Train Epoch 0 Progress: 64.0%	Loss: 0.2161
# Train Epoch 0 Progress: 65.07%	Loss: 0.3424
# Train Epoch 0 Progress: 66.13%	Loss: 0.2582
# Train Epoch 0 Progress: 67.2%	Loss: 0.5434
# Train Epoch 0 Progress: 68.27%	Loss: 0.2943
# Train Epoch 0 Progress: 69.33%	Loss: 0.1563
# Train Epoch 0 Progress: 70.4%	Loss: 0.2629
# Train Epoch 0 Progress: 71.47%	Loss: 0.3726
# Train Epoch 0 Progress: 72.53%	Loss: 0.2803
# Train Epoch 0 Progress: 73.6%	Loss: 0.236
# Train Epoch 0 Progress: 74.67%	Loss: 0.308
# Train Epoch 0 Progress: 75.73%	Loss: 0.3028
# Train Epoch 0 Progress: 76.8%	Loss: 0.4685
# Train Epoch 0 Progress: 77.87%	Loss: 0.2159
# Train Epoch 0 Progress: 78.93%	Loss: 0.2855
# Train Epoch 0 Progress: 80.0%	Loss: 0.2667
# Train Epoch 0 Progress: 81.07%	Loss: 0.1795
# Train Epoch 0 Progress: 82.13%	Loss: 0.6635
# Train Epoch 0 Progress: 83.2%	Loss: 0.2375
# Train Epoch 0 Progress: 84.27%	Loss: 0.2901
# Train Epoch 0 Progress: 85.33%	Loss: 0.2968
# Train Epoch 0 Progress: 86.4%	Loss: 0.2361
# Train Epoch 0 Progress: 87.47%	Loss: 0.2339
# Train Epoch 0 Progress: 88.53%	Loss: 0.375
# Train Epoch 0 Progress: 89.6%	Loss: 0.4042
# Train Epoch 0 Progress: 90.67%	Loss: 0.2404
# Train Epoch 0 Progress: 91.73%	Loss: 0.2266
# Train Epoch 0 Progress: 92.8%	Loss: 0.6043
# Train Epoch 0 Progress: 93.87%	Loss: 0.3002
# Train Epoch 0 Progress: 94.93%	Loss: 0.3424
# Train Epoch 0 Progress: 96.0%	Loss: 0.3207
# Train Epoch 0 Progress: 97.07%	Loss: 0.275
# Train Epoch 0 Progress: 98.13%	Loss: 0.5395
# Train Epoch 0 Progress: 99.2%	Loss: 0.202
#
# Test set: Avg loss 0.0859, Accuracy 97.19%
#
# Train Epoch 1 Progress: 0.0%	Loss: 0.2493
# Train Epoch 1 Progress: 1.07%	Loss: 0.32
# Train Epoch 1 Progress: 2.13%	Loss: 0.4545
# Train Epoch 1 Progress: 3.2%	Loss: 0.1399
# Train Epoch 1 Progress: 4.27%	Loss: 0.2519
# Train Epoch 1 Progress: 5.33%	Loss: 0.1706
# Train Epoch 1 Progress: 6.4%	Loss: 0.1713
# Train Epoch 1 Progress: 7.47%	Loss: 0.2435
# Train Epoch 1 Progress: 8.53%	Loss: 0.2779
# Train Epoch 1 Progress: 9.6%	Loss: 0.2618
# Train Epoch 1 Progress: 10.67%	Loss: 0.2016
# Train Epoch 1 Progress: 11.73%	Loss: 0.3063
# Train Epoch 1 Progress: 12.8%	Loss: 0.1203
# Train Epoch 1 Progress: 13.87%	Loss: 0.2516
# Train Epoch 1 Progress: 14.93%	Loss: 0.3541
# Train Epoch 1 Progress: 16.0%	Loss: 0.2333
# Train Epoch 1 Progress: 17.07%	Loss: 0.4097
# Train Epoch 1 Progress: 18.13%	Loss: 0.2518
# Train Epoch 1 Progress: 19.2%	Loss: 0.1691
# Train Epoch 1 Progress: 20.27%	Loss: 0.2074
# Train Epoch 1 Progress: 21.33%	Loss: 0.2827
# Train Epoch 1 Progress: 22.4%	Loss: 0.1826
# Train Epoch 1 Progress: 23.47%	Loss: 0.3505
# Train Epoch 1 Progress: 24.53%	Loss: 0.1197
# Train Epoch 1 Progress: 25.6%	Loss: 0.3157
# Train Epoch 1 Progress: 26.67%	Loss: 0.2697
# Train Epoch 1 Progress: 27.73%	Loss: 0.1509
# Train Epoch 1 Progress: 28.8%	Loss: 0.3098
# Train Epoch 1 Progress: 29.87%	Loss: 0.4142
# Train Epoch 1 Progress: 30.93%	Loss: 0.4576
# Train Epoch 1 Progress: 32.0%	Loss: 0.2461
# Train Epoch 1 Progress: 33.07%	Loss: 0.2154
# Train Epoch 1 Progress: 34.13%	Loss: 0.2136
# Train Epoch 1 Progress: 35.2%	Loss: 0.1781
# Train Epoch 1 Progress: 36.27%	Loss: 0.4047
# Train Epoch 1 Progress: 37.33%	Loss: 0.1613
# Train Epoch 1 Progress: 38.4%	Loss: 0.411
# Train Epoch 1 Progress: 39.47%	Loss: 0.1877
# Train Epoch 1 Progress: 40.53%	Loss: 0.1122
# Train Epoch 1 Progress: 41.6%	Loss: 0.2391
# Train Epoch 1 Progress: 42.67%	Loss: 0.091
# Train Epoch 1 Progress: 43.73%	Loss: 0.2609
# Train Epoch 1 Progress: 44.8%	Loss: 0.3664
# Train Epoch 1 Progress: 45.87%	Loss: 0.2228
# Train Epoch 1 Progress: 46.93%	Loss: 0.2093
# Train Epoch 1 Progress: 48.0%	Loss: 0.2508
# Train Epoch 1 Progress: 49.07%	Loss: 0.1288
# Train Epoch 1 Progress: 50.13%	Loss: 0.2246
# Train Epoch 1 Progress: 51.2%	Loss: 0.2609
# Train Epoch 1 Progress: 52.27%	Loss: 0.176
# Train Epoch 1 Progress: 53.33%	Loss: 0.1156
# Train Epoch 1 Progress: 54.4%	Loss: 0.1896
# Train Epoch 1 Progress: 55.47%	Loss: 0.2315
# Train Epoch 1 Progress: 56.53%	Loss: 0.346
# Train Epoch 1 Progress: 57.6%	Loss: 0.1975
# Train Epoch 1 Progress: 58.67%	Loss: 0.3501
# Train Epoch 1 Progress: 59.73%	Loss: 0.1074
# Train Epoch 1 Progress: 60.8%	Loss: 0.4179
# Train Epoch 1 Progress: 61.87%	Loss: 0.1551
# Train Epoch 1 Progress: 62.93%	Loss: 0.2821
# Train Epoch 1 Progress: 64.0%	Loss: 0.2017
# Train Epoch 1 Progress: 65.07%	Loss: 0.2525
# Train Epoch 1 Progress: 66.13%	Loss: 0.0791
# Train Epoch 1 Progress: 67.2%	Loss: 0.4078
# Train Epoch 1 Progress: 68.27%	Loss: 0.1914
# Train Epoch 1 Progress: 69.33%	Loss: 0.1607
# Train Epoch 1 Progress: 70.4%	Loss: 0.1253
# Train Epoch 1 Progress: 71.47%	Loss: 0.7178
# Train Epoch 1 Progress: 72.53%	Loss: 0.1564
# Train Epoch 1 Progress: 73.6%	Loss: 0.1723
# Train Epoch 1 Progress: 74.67%	Loss: 0.159
# Train Epoch 1 Progress: 75.73%	Loss: 0.1024
# Train Epoch 1 Progress: 76.8%	Loss: 0.1183
# Train Epoch 1 Progress: 77.87%	Loss: 0.1369
# Train Epoch 1 Progress: 78.93%	Loss: 0.1496
# Train Epoch 1 Progress: 80.0%	Loss: 0.0851
# Train Epoch 1 Progress: 81.07%	Loss: 0.1607
# Train Epoch 1 Progress: 82.13%	Loss: 0.1133
# Train Epoch 1 Progress: 83.2%	Loss: 0.6576
# Train Epoch 1 Progress: 84.27%	Loss: 0.0616
# Train Epoch 1 Progress: 85.33%	Loss: 0.3602
# Train Epoch 1 Progress: 86.4%	Loss: 0.1994
# Train Epoch 1 Progress: 87.47%	Loss: 0.1668
# Train Epoch 1 Progress: 88.53%	Loss: 0.2009
# Train Epoch 1 Progress: 89.6%	Loss: 0.2535
# Train Epoch 1 Progress: 90.67%	Loss: 0.352
# Train Epoch 1 Progress: 91.73%	Loss: 0.2081
# Train Epoch 1 Progress: 92.8%	Loss: 0.2351
# Train Epoch 1 Progress: 93.87%	Loss: 0.1315
# Train Epoch 1 Progress: 94.93%	Loss: 0.1835
# Train Epoch 1 Progress: 96.0%	Loss: 0.1904
# Train Epoch 1 Progress: 97.07%	Loss: 0.3094
# Train Epoch 1 Progress: 98.13%	Loss: 0.1671
# Train Epoch 1 Progress: 99.2%	Loss: 0.2178
#
# Test set: Avg loss 0.0639, Accuracy 97.98%

# %% [markdown]
# #### TASK 3: Assess the Performance of your Model

# %%
import matplotlib.pyplot as plt
import seaborn as sns

def plot_results(test_accuracies, test_losses, train_losses):
    """
    Plot training losses, test losses, and test accuracy over time.

    Parameters:
    - test_accuracies: List of tuples [(epoch, accuracy)], representing test accuracy over epochs.
    - test_losses: List of tuples [(epoch, loss)], representing test loss over examples seen.
    - train_losses: List of tuples [(example, loss)], representing training loss over examples seen.
    """
    # --- Plot Training and Test Losses ---
    plt.figure(figsize=(12, 6))

    # Extract values for training losses
    train_x, train_y = zip(*train_losses)

    # Extract values for test losses
    test_x, test_y = zip(*test_losses)

    # Plot training losses
    plt.plot(train_x, train_y, label='Training Loss', color='b', linestyle='-', marker='.')

    # Plot test losses
    plt.plot(test_x, test_y, label='Test Loss', color='r', linestyle='--', marker='o')

    # Formatting
    plt.xlabel('Examples Seen')
    plt.ylabel('Log Loss')
    plt.title('Training and Test Losses Over Time')
    plt.legend()
    plt.grid(True)
    plt.show()

    # --- Plot Test Accuracy ---
    plt.figure(figsize=(12, 6))

    # Extract values for test accuracy
    acc_x, acc_y = zip(*test_accuracies)

    # Plot test accuracy
    plt.plot(acc_x, acc_y, label='Test Accuracy', color='g', marker='o')

    # Formatting
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.title('Test Accuracy Over Epochs')
    plt.legend()
    plt.grid(True)
    sns.despine()
    plt.show()

# %%
# TASK 3 EXERCISE

# Plot your Results using the function `plot_resolts
plot_results(test_accuracies, test_losses, train_losses)

# %% [markdown]
# # Appendices

# %% [markdown]
# ## Hyperparameter Tuning with CNNs

# %% [markdown]
# ### EXERCISE: Perform Hyperparameter Tuning to Improve Performance of your Convolutional Neural Network

# %%
from itertools import product

# Define ranges for hyperparameters
learning_rates = [0.001, 0.01, 0.1]
momentums = [0.5, 0.9]
batch_sizes = [32, 64, 128]

# Store results
results = []

# Hyperparameter tuning loop
for lr, momentum, batch_size in product(learning_rates, momentums, batch_sizes):
    print(f"Training with lr={lr}, momentum={momentum}, batch_size={batch_size}")

    # Update train loader with the current batch size
    train_loader = torch.utils.data.DataLoader(
        torchvision.datasets.MNIST('sample_data/', train=True, download=True,
                                   transform=torchvision.transforms.Compose([
                                       torchvision.transforms.ToTensor(),
                                       torchvision.transforms.Normalize((0.1307,), (0.3081,))
                                   ])),
        batch_size=batch_size, shuffle=True)

    # Initialize network
    conv_network = ConvNet()
    conv_network.to(device)

    # Define optimizer
    conv_optimizer = optim.SGD(conv_network.parameters(), lr=lr, momentum=momentum)

    # Train and test
    test_accuracies, test_losses, train_losses = list(), list(), list()
    total_examples_seen = 0
    for epoch in range(n_epochs):
        test_loss, test_accuracy = test(conv_network, flatten_data=False)
        train_loss_logs = train(conv_network, conv_optimizer, epoch, train_loader, flatten_data=False)
        test_accuracies.append((epoch, test_accuracy))
        test_losses.append((total_examples_seen, test_loss))
        train_losses.extend(train_loss_logs)
        total_examples_seen = train_loss_logs[-1][0]
    test_loss, test_accuracy = test(conv_network, flatten_data=False)

    # Log the performance
    results.append({
        "lr": lr,
        "momentum": momentum,
        "batch_size": batch_size,
        "test_loss": test_loss,
        "test_accuracy": test_accuracy
    })
# Out:
# Training with lr=0.001, momentum=0.5, batch_size=32
#
# Test set: Avg loss 2.3033, Accuracy 10.21%
#
# Train Epoch 0 Progress: 0.0%	Loss: 2.3597
# Train Epoch 0 Progress: 0.53%	Loss: 2.348
# Train Epoch 0 Progress: 1.07%	Loss: 2.3295
# Train Epoch 0 Progress: 1.6%	Loss: 2.3603
# Train Epoch 0 Progress: 2.13%	Loss: 2.3283
# Train Epoch 0 Progress: 2.67%	Loss: 2.2703
# Train Epoch 0 Progress: 3.2%	Loss: 2.3827
# Train Epoch 0 Progress: 3.73%	Loss: 2.2986
# Train Epoch 0 Progress: 4.27%	Loss: 2.3194
# Train Epoch 0 Progress: 4.8%	Loss: 2.3021
# Train Epoch 0 Progress: 5.33%	Loss: 2.3142
# Train Epoch 0 Progress: 5.87%	Loss: 2.2588
# Train Epoch 0 Progress: 6.4%	Loss: 2.2841
# Train Epoch 0 Progress: 6.93%	Loss: 2.362
# Train Epoch 0 Progress: 7.47%	Loss: 2.3289
# Train Epoch 0 Progress: 8.0%	Loss: 2.298
# Train Epoch 0 Progress: 8.53%	Loss: 2.2932
# Train Epoch 0 Progress: 9.07%	Loss: 2.2765
# Train Epoch 0 Progress: 9.6%	Loss: 2.2856
# Train Epoch 0 Progress: 10.13%	Loss: 2.39
# Train Epoch 0 Progress: 10.67%	Loss: 2.2885
# Train Epoch 0 Progress: 11.2%	Loss: 2.2895
# Train Epoch 0 Progress: 11.73%	Loss: 2.2469
# Train Epoch 0 Progress: 12.27%	Loss: 2.2685
# Train Epoch 0 Progress: 12.8%	Loss: 2.2343
# Train Epoch 0 Progress: 13.33%	Loss: 2.2316
# Train Epoch 0 Progress: 13.87%	Loss: 2.3106
# Train Epoch 0 Progress: 14.4%	Loss: 2.2488
# Train Epoch 0 Progress: 14.93%	Loss: 2.3529
# Train Epoch 0 Progress: 15.47%	Loss: 2.214
# Train Epoch 0 Progress: 16.0%	Loss: 2.2803
# Train Epoch 0 Progress: 16.53%	Loss: 2.3055
# Train Epoch 0 Progress: 17.07%	Loss: 2.2208
# Train Epoch 0 Progress: 17.6%	Loss: 2.2467
# Train Epoch 0 Progress: 18.13%	Loss: 2.2429
# Train Epoch 0 Progress: 18.67%	Loss: 2.2422
# Train Epoch 0 Progress: 19.2%	Loss: 2.2956
# Train Epoch 0 Progress: 19.73%	Loss: 2.2761
# Train Epoch 0 Progress: 20.27%	Loss: 2.2847
# Train Epoch 0 Progress: 20.8%	Loss: 2.2299
# Train Epoch 0 Progress: 21.33%	Loss: 2.219
# Train Epoch 0 Progress: 21.87%	Loss: 2.271
# Train Epoch 0 Progress: 22.4%	Loss: 2.2613
# Train Epoch 0 Progress: 22.93%	Loss: 2.2122
# Train Epoch 0 Progress: 23.47%	Loss: 2.2584
# Train Epoch 0 Progress: 24.0%	Loss: 2.2279
# Train Epoch 0 Progress: 24.53%	Loss: 2.2639
# Train Epoch 0 Progress: 25.07%	Loss: 2.2296
# Train Epoch 0 Progress: 25.6%	Loss: 2.2172
# Train Epoch 0 Progress: 26.13%	Loss: 2.1997
# Train Epoch 0 Progress: 26.67%	Loss: 2.1829
# Train Epoch 0 Progress: 27.2%	Loss: 2.2477
# Train Epoch 0 Progress: 27.73%	Loss: 2.2127
# Train Epoch 0 Progress: 28.27%	Loss: 2.2476
# Train Epoch 0 Progress: 28.8%	Loss: 2.1801
# Train Epoch 0 Progress: 29.33%	Loss: 2.296
# Train Epoch 0 Progress: 29.87%	Loss: 2.2273
# Train Epoch 0 Progress: 30.4%	Loss: 2.2442
# Train Epoch 0 Progress: 30.93%	Loss: 2.1931
# Train Epoch 0 Progress: 31.47%	Loss: 2.2391
# Train Epoch 0 Progress: 32.0%	Loss: 2.2381
# Train Epoch 0 Progress: 32.53%	Loss: 2.2169
# Train Epoch 0 Progress: 33.07%	Loss: 2.2187
# Train Epoch 0 Progress: 33.6%	Loss: 2.1862
# Train Epoch 0 Progress: 34.13%	Loss: 2.1497
# Train Epoch 0 Progress: 34.67%	Loss: 2.166
# Train Epoch 0 Progress: 35.2%	Loss: 2.1587
# Train Epoch 0 Progress: 35.73%	Loss: 2.1345
# Train Epoch 0 Progress: 36.27%	Loss: 2.141
# Train Epoch 0 Progress: 36.8%	Loss: 2.0802
# Train Epoch 0 Progress: 37.33%	Loss: 2.1475
# Train Epoch 0 Progress: 37.87%	Loss: 2.2055
# Train Epoch 0 Progress: 38.4%	Loss: 2.1735
# Train Epoch 0 Progress: 38.93%	Loss: 2.1268
# Train Epoch 0 Progress: 39.47%	Loss: 2.1948
# Train Epoch 0 Progress: 40.0%	Loss: 2.141
# Train Epoch 0 Progress: 40.53%	Loss: 2.1697
# Train Epoch 0 Progress: 41.07%	Loss: 2.1016
# Train Epoch 0 Progress: 41.6%	Loss: 2.1959
# Train Epoch 0 Progress: 42.13%	Loss: 2.107
# Train Epoch 0 Progress: 42.67%	Loss: 2.1264
# Train Epoch 0 Progress: 43.2%	Loss: 2.1723
# Train Epoch 0 Progress: 43.73%	Loss: 2.206
# Train Epoch 0 Progress: 44.27%	Loss: 2.1266
# Train Epoch 0 Progress: 44.8%	Loss: 2.0005
# Train Epoch 0 Progress: 45.33%	Loss: 2.0782
# Train Epoch 0 Progress: 45.87%	Loss: 2.0779
# Train Epoch 0 Progress: 46.4%	Loss: 2.0954
# Train Epoch 0 Progress: 46.93%	Loss: 2.0249
# Train Epoch 0 Progress: 47.47%	Loss: 1.9777
# Train Epoch 0 Progress: 48.0%	Loss: 1.9402
# Train Epoch 0 Progress: 48.53%	Loss: 2.1664
# Train Epoch 0 Progress: 49.07%	Loss: 2.0479
# Train Epoch 0 Progress: 49.6%	Loss: 2.1037
# Train Epoch 0 Progress: 50.13%	Loss: 2.0705
# Train Epoch 0 Progress: 50.67%	Loss: 2.0343
# Train Epoch 0 Progress: 51.2%	Loss: 1.9606
# Train Epoch 0 Progress: 51.73%	Loss: 1.9321
# Train Epoch 0 Progress: 52.27%	Loss: 1.9985
# Train Epoch 0 Progress: 52.8%	Loss: 1.8139
# Train Epoch 0 Progress: 53.33%	Loss: 1.884
# Train Epoch 0 Progress: 53.87%	Loss: 1.8608
# Train Epoch 0 Progress: 54.4%	Loss: 1.7914
# Train Epoch 0 Progress: 54.93%	Loss: 1.967
# Train Epoch 0 Progress: 55.47%	Loss: 1.852
# Train Epoch 0 Progress: 56.0%	Loss: 1.8909
# Train Epoch 0 Progress: 56.53%	Loss: 2.1088
# Train Epoch 0 Progress: 57.07%	Loss: 1.852
# Train Epoch 0 Progress: 57.6%	Loss: 1.8025
# Train Epoch 0 Progress: 58.13%	Loss: 1.8584
# Train Epoch 0 Progress: 58.67%	Loss: 1.8875
# Train Epoch 0 Progress: 59.2%	Loss: 1.5466
# Train Epoch 0 Progress: 59.73%	Loss: 1.8466
# Train Epoch 0 Progress: 60.27%	Loss: 1.6744
# Train Epoch 0 Progress: 60.8%	Loss: 1.7044
# Train Epoch 0 Progress: 61.33%	Loss: 1.7151
# Train Epoch 0 Progress: 61.87%	Loss: 1.8131
# Train Epoch 0 Progress: 62.4%	Loss: 1.7405
# Train Epoch 0 Progress: 62.93%	Loss: 1.9356
# Train Epoch 0 Progress: 63.47%	Loss: 1.7617
# Train Epoch 0 Progress: 64.0%	Loss: 1.9429
# Train Epoch 0 Progress: 64.53%	Loss: 1.8388
# Train Epoch 0 Progress: 65.07%	Loss: 1.5793
# Train Epoch 0 Progress: 65.6%	Loss: 1.8902
# Train Epoch 0 Progress: 66.13%	Loss: 1.7893
# Train Epoch 0 Progress: 66.67%	Loss: 1.8799
# Train Epoch 0 Progress: 67.2%	Loss: 1.673
# Train Epoch 0 Progress: 67.73%	Loss: 1.5017
# Train Epoch 0 Progress: 68.27%	Loss: 1.3342
# Train Epoch 0 Progress: 68.8%	Loss: 1.5891
# Train Epoch 0 Progress: 69.33%	Loss: 1.8104
# Train Epoch 0 Progress: 69.87%	Loss: 1.4677
# Train Epoch 0 Progress: 70.4%	Loss: 1.5548
# Train Epoch 0 Progress: 70.93%	Loss: 1.436
# Train Epoch 0 Progress: 71.47%	Loss: 1.8219
# Train Epoch 0 Progress: 72.0%	Loss: 1.8027
# Train Epoch 0 Progress: 72.53%	Loss: 1.5351
# Train Epoch 0 Progress: 73.07%	Loss: 1.5119
# Train Epoch 0 Progress: 73.6%	Loss: 1.5383
# Train Epoch 0 Progress: 74.13%	Loss: 1.5872
# Train Epoch 0 Progress: 74.67%	Loss: 1.4643
# Train Epoch 0 Progress: 75.2%	Loss: 1.707
# Train Epoch 0 Progress: 75.73%	Loss: 1.4757
# Train Epoch 0 Progress: 76.27%	Loss: 1.433
# Train Epoch 0 Progress: 76.8%	Loss: 1.6477
# Train Epoch 0 Progress: 77.33%	Loss: 1.6118
# Train Epoch 0 Progress: 77.87%	Loss: 1.3589
# Train Epoch 0 Progress: 78.4%	Loss: 1.4322
# Train Epoch 0 Progress: 78.93%	Loss: 1.405
# Train Epoch 0 Progress: 79.47%	Loss: 1.3151
# Train Epoch 0 Progress: 80.0%	Loss: 1.5318
# Train Epoch 0 Progress: 80.53%	Loss: 1.5968
# Train Epoch 0 Progress: 81.07%	Loss: 1.44
# Train Epoch 0 Progress: 81.6%	Loss: 1.6892
# Train Epoch 0 Progress: 82.13%	Loss: 1.4908
# Train Epoch 0 Progress: 82.67%	Loss: 1.4714
# Train Epoch 0 Progress: 83.2%	Loss: 1.5069
# Train Epoch 0 Progress: 83.73%	Loss: 1.1621
# Train Epoch 0 Progress: 84.27%	Loss: 1.5729
# Train Epoch 0 Progress: 84.8%	Loss: 1.3508
# Train Epoch 0 Progress: 85.33%	Loss: 1.5095
# Train Epoch 0 Progress: 85.87%	Loss: 1.5059
# Train Epoch 0 Progress: 86.4%	Loss: 1.6465
# Train Epoch 0 Progress: 86.93%	Loss: 1.1564
# Train Epoch 0 Progress: 87.47%	Loss: 1.2349
# Train Epoch 0 Progress: 88.0%	Loss: 1.3161
# Train Epoch 0 Progress: 88.53%	Loss: 1.2483
# Train Epoch 0 Progress: 89.07%	Loss: 1.2099
# Train Epoch 0 Progress: 89.6%	Loss: 1.458
# Train Epoch 0 Progress: 90.13%	Loss: 1.3979
# Train Epoch 0 Progress: 90.67%	Loss: 1.5759
# Train Epoch 0 Progress: 91.2%	Loss: 1.0087
# Train Epoch 0 Progress: 91.73%	Loss: 1.4994
# Train Epoch 0 Progress: 92.27%	Loss: 1.3619
# Train Epoch 0 Progress: 92.8%	Loss: 1.4948
# Train Epoch 0 Progress: 93.33%	Loss: 1.3331
# Train Epoch 0 Progress: 93.87%	Loss: 1.2531
# Train Epoch 0 Progress: 94.4%	Loss: 1.2076
# Train Epoch 0 Progress: 94.93%	Loss: 1.3872
# Train Epoch 0 Progress: 95.47%	Loss: 1.1996
# Train Epoch 0 Progress: 96.0%	Loss: 1.1884
# Train Epoch 0 Progress: 96.53%	Loss: 1.0047
# Train Epoch 0 Progress: 97.07%	Loss: 1.2285
# Train Epoch 0 Progress: 97.6%	Loss: 1.0873
# Train Epoch 0 Progress: 98.13%	Loss: 1.1123
# Train Epoch 0 Progress: 98.67%	Loss: 1.2297
# Train Epoch 0 Progress: 99.2%	Loss: 1.307
# Train Epoch 0 Progress: 99.73%	Loss: 1.259
#
# Test set: Avg loss 0.8586, Accuracy 80.24%
#
# Train Epoch 1 Progress: 0.0%	Loss: 0.9868
# Train Epoch 1 Progress: 0.53%	Loss: 1.3675
# Train Epoch 1 Progress: 1.07%	Loss: 1.167
# Train Epoch 1 Progress: 1.6%	Loss: 1.1731
# Train Epoch 1 Progress: 2.13%	Loss: 1.1086
# Train Epoch 1 Progress: 2.67%	Loss: 1.1583
# Train Epoch 1 Progress: 3.2%	Loss: 1.3031
# Train Epoch 1 Progress: 3.73%	Loss: 1.1894
# Train Epoch 1 Progress: 4.27%	Loss: 1.3443
# Train Epoch 1 Progress: 4.8%	Loss: 1.6108
# Train Epoch 1 Progress: 5.33%	Loss: 1.3099
# Train Epoch 1 Progress: 5.87%	Loss: 1.0088
# Train Epoch 1 Progress: 6.4%	Loss: 1.1511
# Train Epoch 1 Progress: 6.93%	Loss: 1.4117
# Train Epoch 1 Progress: 7.47%	Loss: 1.1681
# Train Epoch 1 Progress: 8.0%	Loss: 1.2129
# Train Epoch 1 Progress: 8.53%	Loss: 1.4182
# Train Epoch 1 Progress: 9.07%	Loss: 0.8053
# Train Epoch 1 Progress: 9.6%	Loss: 1.2693
# Train Epoch 1 Progress: 10.13%	Loss: 1.1375
# Train Epoch 1 Progress: 10.67%	Loss: 1.193
# Train Epoch 1 Progress: 11.2%	Loss: 0.9667
# Train Epoch 1 Progress: 11.73%	Loss: 1.156
# Train Epoch 1 Progress: 12.27%	Loss: 1.048
# Train Epoch 1 Progress: 12.8%	Loss: 1.0862
# Train Epoch 1 Progress: 13.33%	Loss: 0.8086
# Train Epoch 1 Progress: 13.87%	Loss: 1.2067
# Train Epoch 1 Progress: 14.4%	Loss: 1.1815
# Train Epoch 1 Progress: 14.93%	Loss: 1.0235
# Train Epoch 1 Progress: 15.47%	Loss: 1.1235
# Train Epoch 1 Progress: 16.0%	Loss: 1.0343
# Train Epoch 1 Progress: 16.53%	Loss: 1.039
# Train Epoch 1 Progress: 17.07%	Loss: 1.0957
# Train Epoch 1 Progress: 17.6%	Loss: 1.4906
# Train Epoch 1 Progress: 18.13%	Loss: 0.9258
# Train Epoch 1 Progress: 18.67%	Loss: 0.962
# Train Epoch 1 Progress: 19.2%	Loss: 1.19
# Train Epoch 1 Progress: 19.73%	Loss: 1.273
# Train Epoch 1 Progress: 20.27%	Loss: 0.6626
# Train Epoch 1 Progress: 20.8%	Loss: 1.2084
# Train Epoch 1 Progress: 21.33%	Loss: 1.3594
# Train Epoch 1 Progress: 21.87%	Loss: 1.0852
# Train Epoch 1 Progress: 22.4%	Loss: 0.9424
# Train Epoch 1 Progress: 22.93%	Loss: 0.9801
# Train Epoch 1 Progress: 23.47%	Loss: 0.9365
# Train Epoch 1 Progress: 24.0%	Loss: 1.0778
# Train Epoch 1 Progress: 24.53%	Loss: 0.9779
# Train Epoch 1 Progress: 25.07%	Loss: 0.7969
# Train Epoch 1 Progress: 25.6%	Loss: 1.0385
# Train Epoch 1 Progress: 26.13%	Loss: 1.0084
# Train Epoch 1 Progress: 26.67%	Loss: 1.0768
# Train Epoch 1 Progress: 27.2%	Loss: 0.8599
# Train Epoch 1 Progress: 27.73%	Loss: 1.1447
# Train Epoch 1 Progress: 28.27%	Loss: 1.0353
# Train Epoch 1 Progress: 28.8%	Loss: 0.8257
# Train Epoch 1 Progress: 29.33%	Loss: 1.0242
# Train Epoch 1 Progress: 29.87%	Loss: 0.9898
# Train Epoch 1 Progress: 30.4%	Loss: 0.774
# Train Epoch 1 Progress: 30.93%	Loss: 1.0163
# Train Epoch 1 Progress: 31.47%	Loss: 0.9709
# Train Epoch 1 Progress: 32.0%	Loss: 1.1821
# Train Epoch 1 Progress: 32.53%	Loss: 0.9025
# Train Epoch 1 Progress: 33.07%	Loss: 0.8619
# Train Epoch 1 Progress: 33.6%	Loss: 1.0641
# Train Epoch 1 Progress: 34.13%	Loss: 1.0701
# Train Epoch 1 Progress: 34.67%	Loss: 0.9699
# Train Epoch 1 Progress: 35.2%	Loss: 1.2389
# Train Epoch 1 Progress: 35.73%	Loss: 0.9642
# Train Epoch 1 Progress: 36.27%	Loss: 0.8404
# Train Epoch 1 Progress: 36.8%	Loss: 0.8771
# Train Epoch 1 Progress: 37.33%	Loss: 0.8218
# Train Epoch 1 Progress: 37.87%	Loss: 1.0956
# Train Epoch 1 Progress: 38.4%	Loss: 0.7936
# Train Epoch 1 Progress: 38.93%	Loss: 0.823
# Train Epoch 1 Progress: 39.47%	Loss: 0.5793
# Train Epoch 1 Progress: 40.0%	Loss: 0.962
# Train Epoch 1 Progress: 40.53%	Loss: 1.0726
# Train Epoch 1 Progress: 41.07%	Loss: 0.8869
# Train Epoch 1 Progress: 41.6%	Loss: 0.859
# Train Epoch 1 Progress: 42.13%	Loss: 1.0196
# Train Epoch 1 Progress: 42.67%	Loss: 1.2175
# Train Epoch 1 Progress: 43.2%	Loss: 0.9332
# Train Epoch 1 Progress: 43.73%	Loss: 0.872
# Train Epoch 1 Progress: 44.27%	Loss: 0.9942
# Train Epoch 1 Progress: 44.8%	Loss: 1.003
# Train Epoch 1 Progress: 45.33%	Loss: 1.1026
# Train Epoch 1 Progress: 45.87%	Loss: 0.7339
# Train Epoch 1 Progress: 46.4%	Loss: 0.6508
# Train Epoch 1 Progress: 46.93%	Loss: 0.5343
# Train Epoch 1 Progress: 47.47%	Loss: 0.562
# Train Epoch 1 Progress: 48.0%	Loss: 0.7142
# Train Epoch 1 Progress: 48.53%	Loss: 1.1215
# Train Epoch 1 Progress: 49.07%	Loss: 0.6938
# Train Epoch 1 Progress: 49.6%	Loss: 0.9749
# Train Epoch 1 Progress: 50.13%	Loss: 0.6553
# Train Epoch 1 Progress: 50.67%	Loss: 1.3236
# Train Epoch 1 Progress: 51.2%	Loss: 0.9387
# Train Epoch 1 Progress: 51.73%	Loss: 0.7724
# Train Epoch 1 Progress: 52.27%	Loss: 0.8288
# Train Epoch 1 Progress: 52.8%	Loss: 0.7255
# Train Epoch 1 Progress: 53.33%	Loss: 0.9554
# Train Epoch 1 Progress: 53.87%	Loss: 1.1174
# Train Epoch 1 Progress: 54.4%	Loss: 0.9462
# Train Epoch 1 Progress: 54.93%	Loss: 0.7263
# Train Epoch 1 Progress: 55.47%	Loss: 0.575
# Train Epoch 1 Progress: 56.0%	Loss: 0.885
# Train Epoch 1 Progress: 56.53%	Loss: 0.6705
# Train Epoch 1 Progress: 57.07%	Loss: 0.8833
# Train Epoch 1 Progress: 57.6%	Loss: 0.9696
# Train Epoch 1 Progress: 58.13%	Loss: 0.793
# Train Epoch 1 Progress: 58.67%	Loss: 0.772
# Train Epoch 1 Progress: 59.2%	Loss: 0.4121
# Train Epoch 1 Progress: 59.73%	Loss: 0.7022
# Train Epoch 1 Progress: 60.27%	Loss: 0.9566
# Train Epoch 1 Progress: 60.8%	Loss: 0.6065
# Train Epoch 1 Progress: 61.33%	Loss: 0.7919
# Train Epoch 1 Progress: 61.87%	Loss: 0.7593
# Train Epoch 1 Progress: 62.4%	Loss: 0.974
# Train Epoch 1 Progress: 62.93%	Loss: 1.0199
# Train Epoch 1 Progress: 63.47%	Loss: 1.095
# Train Epoch 1 Progress: 64.0%	Loss: 0.6024
# Train Epoch 1 Progress: 64.53%	Loss: 1.154
# Train Epoch 1 Progress: 65.07%	Loss: 0.6152
# Train Epoch 1 Progress: 65.6%	Loss: 0.9556
# Train Epoch 1 Progress: 66.13%	Loss: 0.7305
# Train Epoch 1 Progress: 66.67%	Loss: 0.6156
# Train Epoch 1 Progress: 67.2%	Loss: 0.9389
# Train Epoch 1 Progress: 67.73%	Loss: 0.7763
# Train Epoch 1 Progress: 68.27%	Loss: 0.6898
# Train Epoch 1 Progress: 68.8%	Loss: 0.8976
# Train Epoch 1 Progress: 69.33%	Loss: 0.6545
# Train Epoch 1 Progress: 69.87%	Loss: 0.9101
# Train Epoch 1 Progress: 70.4%	Loss: 0.8622
# Train Epoch 1 Progress: 70.93%	Loss: 0.7906
# Train Epoch 1 Progress: 71.47%	Loss: 0.6518
# Train Epoch 1 Progress: 72.0%	Loss: 0.8388
# Train Epoch 1 Progress: 72.53%	Loss: 0.8748
# Train Epoch 1 Progress: 73.07%	Loss: 0.9565
# Train Epoch 1 Progress: 73.6%	Loss: 0.5738
# Train Epoch 1 Progress: 74.13%	Loss: 0.74
# Train Epoch 1 Progress: 74.67%	Loss: 0.6969
# Train Epoch 1 Progress: 75.2%	Loss: 0.5446
# Train Epoch 1 Progress: 75.73%	Loss: 0.8881
# Train Epoch 1 Progress: 76.27%	Loss: 0.5426
# Train Epoch 1 Progress: 76.8%	Loss: 0.8672
# Train Epoch 1 Progress: 77.33%	Loss: 0.7789
# Train Epoch 1 Progress: 77.87%	Loss: 0.9534
# Train Epoch 1 Progress: 78.4%	Loss: 0.9319
# Train Epoch 1 Progress: 78.93%	Loss: 0.7895
# Train Epoch 1 Progress: 79.47%	Loss: 0.6942
# Train Epoch 1 Progress: 80.0%	Loss: 0.6795
# Train Epoch 1 Progress: 80.53%	Loss: 0.8489
# Train Epoch 1 Progress: 81.07%	Loss: 0.9511
# Train Epoch 1 Progress: 81.6%	Loss: 0.6134
# Train Epoch 1 Progress: 82.13%	Loss: 0.7527
# Train Epoch 1 Progress: 82.67%	Loss: 0.9429
# Train Epoch 1 Progress: 83.2%	Loss: 1.0081
# Train Epoch 1 Progress: 83.73%	Loss: 0.9301
# Train Epoch 1 Progress: 84.27%	Loss: 0.6739
# Train Epoch 1 Progress: 84.8%	Loss: 0.5698
# Train Epoch 1 Progress: 85.33%	Loss: 0.9668
# Train Epoch 1 Progress: 85.87%	Loss: 1.3854
# Train Epoch 1 Progress: 86.4%	Loss: 0.6334
# Train Epoch 1 Progress: 86.93%	Loss: 0.9267
# Train Epoch 1 Progress: 87.47%	Loss: 0.7609
# Train Epoch 1 Progress: 88.0%	Loss: 0.7529
# Train Epoch 1 Progress: 88.53%	Loss: 0.7664
# Train Epoch 1 Progress: 89.07%	Loss: 1.2026
# Train Epoch 1 Progress: 89.6%	Loss: 1.1043
# Train Epoch 1 Progress: 90.13%	Loss: 0.6614
# Train Epoch 1 Progress: 90.67%	Loss: 0.6066
# Train Epoch 1 Progress: 91.2%	Loss: 0.6513
# Train Epoch 1 Progress: 91.73%	Loss: 0.539
# Train Epoch 1 Progress: 92.27%	Loss: 0.7097
# Train Epoch 1 Progress: 92.8%	Loss: 0.8258
# Train Epoch 1 Progress: 93.33%	Loss: 0.7456
# Train Epoch 1 Progress: 93.87%	Loss: 0.839
# Train Epoch 1 Progress: 94.4%	Loss: 0.6621
# Train Epoch 1 Progress: 94.93%	Loss: 0.98
# Train Epoch 1 Progress: 95.47%	Loss: 0.9625
# Train Epoch 1 Progress: 96.0%	Loss: 0.6543
# Train Epoch 1 Progress: 96.53%	Loss: 0.8733
# Train Epoch 1 Progress: 97.07%	Loss: 0.4665
# Train Epoch 1 Progress: 97.6%	Loss: 0.5208
# Train Epoch 1 Progress: 98.13%	Loss: 0.7539
# Train Epoch 1 Progress: 98.67%	Loss: 0.7196
# Train Epoch 1 Progress: 99.2%	Loss: 0.5522
# Train Epoch 1 Progress: 99.73%	Loss: 0.7165
#
# Test set: Avg loss 0.4051, Accuracy 89.58%
#
# Training with lr=0.001, momentum=0.5, batch_size=64
#
# Test set: Avg loss 2.3112, Accuracy 10.17%
#
# Train Epoch 0 Progress: 0.0%	Loss: 2.3647
# Train Epoch 0 Progress: 1.07%	Loss: 2.3316
# Train Epoch 0 Progress: 2.13%	Loss: 2.3235
# Train Epoch 0 Progress: 3.2%	Loss: 2.3435
# Train Epoch 0 Progress: 4.27%	Loss: 2.3486
# Train Epoch 0 Progress: 5.33%	Loss: 2.327
# Train Epoch 0 Progress: 6.4%	Loss: 2.2961
# Train Epoch 0 Progress: 7.47%	Loss: 2.3481
# Train Epoch 0 Progress: 8.53%	Loss: 2.2824
# Train Epoch 0 Progress: 9.6%	Loss: 2.3786
# Train Epoch 0 Progress: 10.67%	Loss: 2.2736
# Train Epoch 0 Progress: 11.73%	Loss: 2.2948
# Train Epoch 0 Progress: 12.8%	Loss: 2.2897
# Train Epoch 0 Progress: 13.87%	Loss: 2.2996
# Train Epoch 0 Progress: 14.93%	Loss: 2.2809
# Train Epoch 0 Progress: 16.0%	Loss: 2.308
# Train Epoch 0 Progress: 17.07%	Loss: 2.2821
# Train Epoch 0 Progress: 18.13%	Loss: 2.2992
# Train Epoch 0 Progress: 19.2%	Loss: 2.2963
# Train Epoch 0 Progress: 20.27%	Loss: 2.2447
# Train Epoch 0 Progress: 21.33%	Loss: 2.2846
# Train Epoch 0 Progress: 22.4%	Loss: 2.2674
# Train Epoch 0 Progress: 23.47%	Loss: 2.2644
# Train Epoch 0 Progress: 24.53%	Loss: 2.2584
# Train Epoch 0 Progress: 25.6%	Loss: 2.2552
# Train Epoch 0 Progress: 26.67%	Loss: 2.2537
# Train Epoch 0 Progress: 27.73%	Loss: 2.2898
# Train Epoch 0 Progress: 28.8%	Loss: 2.2781
# Train Epoch 0 Progress: 29.87%	Loss: 2.2418
# Train Epoch 0 Progress: 30.93%	Loss: 2.2887
# Train Epoch 0 Progress: 32.0%	Loss: 2.2331
# Train Epoch 0 Progress: 33.07%	Loss: 2.2433
# Train Epoch 0 Progress: 34.13%	Loss: 2.2573
# Train Epoch 0 Progress: 35.2%	Loss: 2.2576
# Train Epoch 0 Progress: 36.27%	Loss: 2.2121
# Train Epoch 0 Progress: 37.33%	Loss: 2.2604
# Train Epoch 0 Progress: 38.4%	Loss: 2.1828
# Train Epoch 0 Progress: 39.47%	Loss: 2.2432
# Train Epoch 0 Progress: 40.53%	Loss: 2.1961
# Train Epoch 0 Progress: 41.6%	Loss: 2.2197
# Train Epoch 0 Progress: 42.67%	Loss: 2.2331
# Train Epoch 0 Progress: 43.73%	Loss: 2.2608
# Train Epoch 0 Progress: 44.8%	Loss: 2.1979
# Train Epoch 0 Progress: 45.87%	Loss: 2.1904
# Train Epoch 0 Progress: 46.93%	Loss: 2.1861
# Train Epoch 0 Progress: 48.0%	Loss: 2.2171
# Train Epoch 0 Progress: 49.07%	Loss: 2.1983
# Train Epoch 0 Progress: 50.13%	Loss: 2.181
# Train Epoch 0 Progress: 51.2%	Loss: 2.1985
# Train Epoch 0 Progress: 52.27%	Loss: 2.1783
# Train Epoch 0 Progress: 53.33%	Loss: 2.1921
# Train Epoch 0 Progress: 54.4%	Loss: 2.1925
# Train Epoch 0 Progress: 55.47%	Loss: 2.2417
# Train Epoch 0 Progress: 56.53%	Loss: 2.1204
# Train Epoch 0 Progress: 57.6%	Loss: 2.1615
# Train Epoch 0 Progress: 58.67%	Loss: 2.2172
# Train Epoch 0 Progress: 59.73%	Loss: 2.2079
# Train Epoch 0 Progress: 60.8%	Loss: 2.1458
# Train Epoch 0 Progress: 61.87%	Loss: 2.1637
# Train Epoch 0 Progress: 62.93%	Loss: 2.2053
# Train Epoch 0 Progress: 64.0%	Loss: 2.1659
# Train Epoch 0 Progress: 65.07%	Loss: 2.173
# Train Epoch 0 Progress: 66.13%	Loss: 2.1289
# Train Epoch 0 Progress: 67.2%	Loss: 2.1364
# Train Epoch 0 Progress: 68.27%	Loss: 2.1174
# Train Epoch 0 Progress: 69.33%	Loss: 2.1307
# Train Epoch 0 Progress: 70.4%	Loss: 2.03
# Train Epoch 0 Progress: 71.47%	Loss: 2.1092
# Train Epoch 0 Progress: 72.53%	Loss: 2.0782
# Train Epoch 0 Progress: 73.6%	Loss: 2.0887
# Train Epoch 0 Progress: 74.67%	Loss: 2.0677
# Train Epoch 0 Progress: 75.73%	Loss: 2.1077
# Train Epoch 0 Progress: 76.8%	Loss: 2.132
# Train Epoch 0 Progress: 77.87%	Loss: 1.9942
# Train Epoch 0 Progress: 78.93%	Loss: 2.033
# Train Epoch 0 Progress: 80.0%	Loss: 2.0995
# Train Epoch 0 Progress: 81.07%	Loss: 2.0727
# Train Epoch 0 Progress: 82.13%	Loss: 2.0564
# Train Epoch 0 Progress: 83.2%	Loss: 2.0059
# Train Epoch 0 Progress: 84.27%	Loss: 1.9702
# Train Epoch 0 Progress: 85.33%	Loss: 1.9373
# Train Epoch 0 Progress: 86.4%	Loss: 1.9707
# Train Epoch 0 Progress: 87.47%	Loss: 1.8947
# Train Epoch 0 Progress: 88.53%	Loss: 2.0152
# Train Epoch 0 Progress: 89.6%	Loss: 1.9683
# Train Epoch 0 Progress: 90.67%	Loss: 1.9392
# Train Epoch 0 Progress: 91.73%	Loss: 1.8927
# Train Epoch 0 Progress: 92.8%	Loss: 1.9651
# Train Epoch 0 Progress: 93.87%	Loss: 1.9855
# Train Epoch 0 Progress: 94.93%	Loss: 2.0642
# Train Epoch 0 Progress: 96.0%	Loss: 1.8551
# Train Epoch 0 Progress: 97.07%	Loss: 1.8447
# Train Epoch 0 Progress: 98.13%	Loss: 1.8685
# Train Epoch 0 Progress: 99.2%	Loss: 1.8812
#
# Test set: Avg loss 1.6795, Accuracy 65.69%
#
# Train Epoch 1 Progress: 0.0%	Loss: 1.9225
# Train Epoch 1 Progress: 1.07%	Loss: 1.8504
# Train Epoch 1 Progress: 2.13%	Loss: 1.9407
# Train Epoch 1 Progress: 3.2%	Loss: 1.8344
# Train Epoch 1 Progress: 4.27%	Loss: 1.8724
# Train Epoch 1 Progress: 5.33%	Loss: 1.875
# Train Epoch 1 Progress: 6.4%	Loss: 1.8917
# Train Epoch 1 Progress: 7.47%	Loss: 1.6406
# Train Epoch 1 Progress: 8.53%	Loss: 1.7651
# Train Epoch 1 Progress: 9.6%	Loss: 1.6418
# Train Epoch 1 Progress: 10.67%	Loss: 1.7125
# Train Epoch 1 Progress: 11.73%	Loss: 1.5581
# Train Epoch 1 Progress: 12.8%	Loss: 1.7343
# Train Epoch 1 Progress: 13.87%	Loss: 1.6832
# Train Epoch 1 Progress: 14.93%	Loss: 1.781
# Train Epoch 1 Progress: 16.0%	Loss: 1.6626
# Train Epoch 1 Progress: 17.07%	Loss: 1.6994
# Train Epoch 1 Progress: 18.13%	Loss: 1.5761
# Train Epoch 1 Progress: 19.2%	Loss: 1.5591
# Train Epoch 1 Progress: 20.27%	Loss: 1.6272
# Train Epoch 1 Progress: 21.33%	Loss: 1.6097
# Train Epoch 1 Progress: 22.4%	Loss: 1.6336
# Train Epoch 1 Progress: 23.47%	Loss: 1.7354
# Train Epoch 1 Progress: 24.53%	Loss: 1.5966
# Train Epoch 1 Progress: 25.6%	Loss: 1.578
# Train Epoch 1 Progress: 26.67%	Loss: 1.6361
# Train Epoch 1 Progress: 27.73%	Loss: 1.6291
# Train Epoch 1 Progress: 28.8%	Loss: 1.4761
# Train Epoch 1 Progress: 29.87%	Loss: 1.4138
# Train Epoch 1 Progress: 30.93%	Loss: 1.4636
# Train Epoch 1 Progress: 32.0%	Loss: 1.4154
# Train Epoch 1 Progress: 33.07%	Loss: 1.5246
# Train Epoch 1 Progress: 34.13%	Loss: 1.4781
# Train Epoch 1 Progress: 35.2%	Loss: 1.3604
# Train Epoch 1 Progress: 36.27%	Loss: 1.3872
# Train Epoch 1 Progress: 37.33%	Loss: 1.5181
# Train Epoch 1 Progress: 38.4%	Loss: 1.4554
# Train Epoch 1 Progress: 39.47%	Loss: 1.383
# Train Epoch 1 Progress: 40.53%	Loss: 1.5064
# Train Epoch 1 Progress: 41.6%	Loss: 1.4196
# Train Epoch 1 Progress: 42.67%	Loss: 1.4612
# Train Epoch 1 Progress: 43.73%	Loss: 1.3292
# Train Epoch 1 Progress: 44.8%	Loss: 1.1854
# Train Epoch 1 Progress: 45.87%	Loss: 1.3786
# Train Epoch 1 Progress: 46.93%	Loss: 1.4462
# Train Epoch 1 Progress: 48.0%	Loss: 1.4076
# Train Epoch 1 Progress: 49.07%	Loss: 1.2824
# Train Epoch 1 Progress: 50.13%	Loss: 1.2558
# Train Epoch 1 Progress: 51.2%	Loss: 1.2855
# Train Epoch 1 Progress: 52.27%	Loss: 1.1933
# Train Epoch 1 Progress: 53.33%	Loss: 1.186
# Train Epoch 1 Progress: 54.4%	Loss: 1.1429
# Train Epoch 1 Progress: 55.47%	Loss: 1.3819
# Train Epoch 1 Progress: 56.53%	Loss: 1.6348
# Train Epoch 1 Progress: 57.6%	Loss: 1.3186
# Train Epoch 1 Progress: 58.67%	Loss: 1.3016
# Train Epoch 1 Progress: 59.73%	Loss: 1.2819
# Train Epoch 1 Progress: 60.8%	Loss: 1.2158
# Train Epoch 1 Progress: 61.87%	Loss: 1.4426
# Train Epoch 1 Progress: 62.93%	Loss: 1.4833
# Train Epoch 1 Progress: 64.0%	Loss: 1.1846
# Train Epoch 1 Progress: 65.07%	Loss: 1.3722
# Train Epoch 1 Progress: 66.13%	Loss: 1.3376
# Train Epoch 1 Progress: 67.2%	Loss: 1.1269
# Train Epoch 1 Progress: 68.27%	Loss: 1.3988
# Train Epoch 1 Progress: 69.33%	Loss: 1.0931
# Train Epoch 1 Progress: 70.4%	Loss: 0.9541
# Train Epoch 1 Progress: 71.47%	Loss: 1.0778
# Train Epoch 1 Progress: 72.53%	Loss: 1.1017
# Train Epoch 1 Progress: 73.6%	Loss: 1.0549
# Train Epoch 1 Progress: 74.67%	Loss: 1.244
# Train Epoch 1 Progress: 75.73%	Loss: 1.1806
# Train Epoch 1 Progress: 76.8%	Loss: 1.2259
# Train Epoch 1 Progress: 77.87%	Loss: 1.1567
# Train Epoch 1 Progress: 78.93%	Loss: 1.067
# Train Epoch 1 Progress: 80.0%	Loss: 1.1833
# Train Epoch 1 Progress: 81.07%	Loss: 1.1433
# Train Epoch 1 Progress: 82.13%	Loss: 1.0518
# Train Epoch 1 Progress: 83.2%	Loss: 0.8843
# Train Epoch 1 Progress: 84.27%	Loss: 0.9289
# Train Epoch 1 Progress: 85.33%	Loss: 0.9897
# Train Epoch 1 Progress: 86.4%	Loss: 1.2648
# Train Epoch 1 Progress: 87.47%	Loss: 0.8135
# Train Epoch 1 Progress: 88.53%	Loss: 1.1599
# Train Epoch 1 Progress: 89.6%	Loss: 1.1884
# Train Epoch 1 Progress: 90.67%	Loss: 1.0042
# Train Epoch 1 Progress: 91.73%	Loss: 0.8901
# Train Epoch 1 Progress: 92.8%	Loss: 1.185
# Train Epoch 1 Progress: 93.87%	Loss: 1.2416
# Train Epoch 1 Progress: 94.93%	Loss: 0.8809
# Train Epoch 1 Progress: 96.0%	Loss: 0.9922
# Train Epoch 1 Progress: 97.07%	Loss: 0.9157
# Train Epoch 1 Progress: 98.13%	Loss: 0.8777
# Train Epoch 1 Progress: 99.2%	Loss: 0.9293
#
# Test set: Avg loss 0.6125, Accuracy 85.29%
#
# Training with lr=0.001, momentum=0.5, batch_size=128
#
# Test set: Avg loss 2.3141, Accuracy 5.58%
#
# Train Epoch 0 Progress: 0.0%	Loss: 2.3203
# Train Epoch 0 Progress: 2.13%	Loss: 2.3406
# Train Epoch 0 Progress: 4.27%	Loss: 2.2952
# Train Epoch 0 Progress: 6.4%	Loss: 2.3125
# Train Epoch 0 Progress: 8.53%	Loss: 2.3223
# Train Epoch 0 Progress: 10.67%	Loss: 2.3293
# Train Epoch 0 Progress: 12.8%	Loss: 2.3351
# Train Epoch 0 Progress: 14.93%	Loss: 2.3024
# Train Epoch 0 Progress: 17.07%	Loss: 2.3052
# Train Epoch 0 Progress: 19.2%	Loss: 2.3098
# Train Epoch 0 Progress: 21.33%	Loss: 2.3097
# Train Epoch 0 Progress: 23.47%	Loss: 2.3148
# Train Epoch 0 Progress: 25.6%	Loss: 2.3028
# Train Epoch 0 Progress: 27.73%	Loss: 2.3132
# Train Epoch 0 Progress: 29.87%	Loss: 2.3069
# Train Epoch 0 Progress: 32.0%	Loss: 2.3
# Train Epoch 0 Progress: 34.13%	Loss: 2.2982
# Train Epoch 0 Progress: 36.27%	Loss: 2.3035
# Train Epoch 0 Progress: 38.4%	Loss: 2.2872
# Train Epoch 0 Progress: 40.53%	Loss: 2.2887
# Train Epoch 0 Progress: 42.67%	Loss: 2.294
# Train Epoch 0 Progress: 44.8%	Loss: 2.2969
# Train Epoch 0 Progress: 46.93%	Loss: 2.303
# Train Epoch 0 Progress: 49.07%	Loss: 2.2989
# Train Epoch 0 Progress: 51.2%	Loss: 2.2977
# Train Epoch 0 Progress: 53.33%	Loss: 2.3101
# Train Epoch 0 Progress: 55.47%	Loss: 2.3126
# Train Epoch 0 Progress: 57.6%	Loss: 2.3177
# Train Epoch 0 Progress: 59.73%	Loss: 2.3017
# Train Epoch 0 Progress: 61.87%	Loss: 2.3006
# Train Epoch 0 Progress: 64.0%	Loss: 2.2936
# Train Epoch 0 Progress: 66.13%	Loss: 2.2911
# Train Epoch 0 Progress: 68.27%	Loss: 2.2818
# Train Epoch 0 Progress: 70.4%	Loss: 2.289
# Train Epoch 0 Progress: 72.53%	Loss: 2.2851
# Train Epoch 0 Progress: 74.67%	Loss: 2.2665
# Train Epoch 0 Progress: 76.8%	Loss: 2.2639
# Train Epoch 0 Progress: 78.93%	Loss: 2.2916
# Train Epoch 0 Progress: 81.07%	Loss: 2.2954
# Train Epoch 0 Progress: 83.2%	Loss: 2.2952
# Train Epoch 0 Progress: 85.33%	Loss: 2.2703
# Train Epoch 0 Progress: 87.47%	Loss: 2.2821
# Train Epoch 0 Progress: 89.6%	Loss: 2.2931
# Train Epoch 0 Progress: 91.73%	Loss: 2.2824
# Train Epoch 0 Progress: 93.87%	Loss: 2.2722
# Train Epoch 0 Progress: 96.0%	Loss: 2.2822
# Train Epoch 0 Progress: 98.13%	Loss: 2.2728
#
# Test set: Avg loss 2.2644, Accuracy 22.14%
#
# Train Epoch 1 Progress: 0.0%	Loss: 2.2908
# Train Epoch 1 Progress: 2.13%	Loss: 2.2853
# Train Epoch 1 Progress: 4.27%	Loss: 2.2678
# Train Epoch 1 Progress: 6.4%	Loss: 2.2705
# Train Epoch 1 Progress: 8.53%	Loss: 2.2853
# Train Epoch 1 Progress: 10.67%	Loss: 2.2704
# Train Epoch 1 Progress: 12.8%	Loss: 2.2765
# Train Epoch 1 Progress: 14.93%	Loss: 2.2772
# Train Epoch 1 Progress: 17.07%	Loss: 2.2775
# Train Epoch 1 Progress: 19.2%	Loss: 2.2805
# Train Epoch 1 Progress: 21.33%	Loss: 2.2524
# Train Epoch 1 Progress: 23.47%	Loss: 2.2758
# Train Epoch 1 Progress: 25.6%	Loss: 2.2515
# Train Epoch 1 Progress: 27.73%	Loss: 2.2685
# Train Epoch 1 Progress: 29.87%	Loss: 2.2455
# Train Epoch 1 Progress: 32.0%	Loss: 2.2674
# Train Epoch 1 Progress: 34.13%	Loss: 2.2854
# Train Epoch 1 Progress: 36.27%	Loss: 2.2396
# Train Epoch 1 Progress: 38.4%	Loss: 2.2335
# Train Epoch 1 Progress: 40.53%	Loss: 2.2711
# Train Epoch 1 Progress: 42.67%	Loss: 2.2208
# Train Epoch 1 Progress: 44.8%	Loss: 2.2554
# Train Epoch 1 Progress: 46.93%	Loss: 2.2233
# Train Epoch 1 Progress: 49.07%	Loss: 2.264
# Train Epoch 1 Progress: 51.2%	Loss: 2.2338
# Train Epoch 1 Progress: 53.33%	Loss: 2.2163
# Train Epoch 1 Progress: 55.47%	Loss: 2.2455
# Train Epoch 1 Progress: 57.6%	Loss: 2.2318
# Train Epoch 1 Progress: 59.73%	Loss: 2.2736
# Train Epoch 1 Progress: 61.87%	Loss: 2.233
# Train Epoch 1 Progress: 64.0%	Loss: 2.2607
# Train Epoch 1 Progress: 66.13%	Loss: 2.249
# Train Epoch 1 Progress: 68.27%	Loss: 2.2339
# Train Epoch 1 Progress: 70.4%	Loss: 2.2353
# Train Epoch 1 Progress: 72.53%	Loss: 2.2038
# Train Epoch 1 Progress: 74.67%	Loss: 2.2327
# Train Epoch 1 Progress: 76.8%	Loss: 2.2
# Train Epoch 1 Progress: 78.93%	Loss: 2.2064
# Train Epoch 1 Progress: 81.07%	Loss: 2.2061
# Train Epoch 1 Progress: 83.2%	Loss: 2.2218
# Train Epoch 1 Progress: 85.33%	Loss: 2.1929
# Train Epoch 1 Progress: 87.47%	Loss: 2.2286
# Train Epoch 1 Progress: 89.6%	Loss: 2.1967
# Train Epoch 1 Progress: 91.73%	Loss: 2.1677
# Train Epoch 1 Progress: 93.87%	Loss: 2.2161
# Train Epoch 1 Progress: 96.0%	Loss: 2.1837
# Train Epoch 1 Progress: 98.13%	Loss: 2.1946
#
# Test set: Avg loss 2.1535, Accuracy 45.5%
#
# Training with lr=0.001, momentum=0.9, batch_size=32
#
# Test set: Avg loss 2.3046, Accuracy 7.27%
#
# Train Epoch 0 Progress: 0.0%	Loss: 2.29
# Train Epoch 0 Progress: 0.53%	Loss: 2.3203
# Train Epoch 0 Progress: 1.07%	Loss: 2.3315
# Train Epoch 0 Progress: 1.6%	Loss: 2.2629
# Train Epoch 0 Progress: 2.13%	Loss: 2.2913
# Train Epoch 0 Progress: 2.67%	Loss: 2.2885
# Train Epoch 0 Progress: 3.2%	Loss: 2.295
# Train Epoch 0 Progress: 3.73%	Loss: 2.3059
# Train Epoch 0 Progress: 4.27%	Loss: 2.2697
# Train Epoch 0 Progress: 4.8%	Loss: 2.2212
# Train Epoch 0 Progress: 5.33%	Loss: 2.1937
# Train Epoch 0 Progress: 5.87%	Loss: 2.2057
# Train Epoch 0 Progress: 6.4%	Loss: 2.2164
# Train Epoch 0 Progress: 6.93%	Loss: 2.1415
# Train Epoch 0 Progress: 7.47%	Loss: 2.1616
# Train Epoch 0 Progress: 8.0%	Loss: 2.0934
# Train Epoch 0 Progress: 8.53%	Loss: 2.1087
# Train Epoch 0 Progress: 9.07%	Loss: 2.0767
# Train Epoch 0 Progress: 9.6%	Loss: 2.0482
# Train Epoch 0 Progress: 10.13%	Loss: 1.9912
# Train Epoch 0 Progress: 10.67%	Loss: 1.9921
# Train Epoch 0 Progress: 11.2%	Loss: 2.0512
# Train Epoch 0 Progress: 11.73%	Loss: 1.8643
# Train Epoch 0 Progress: 12.27%	Loss: 1.7171
# Train Epoch 0 Progress: 12.8%	Loss: 1.8101
# Train Epoch 0 Progress: 13.33%	Loss: 1.7949
# Train Epoch 0 Progress: 13.87%	Loss: 1.5656
# Train Epoch 0 Progress: 14.4%	Loss: 1.31
# Train Epoch 0 Progress: 14.93%	Loss: 1.2807
# Train Epoch 0 Progress: 15.47%	Loss: 1.3216
# Train Epoch 0 Progress: 16.0%	Loss: 1.357
# Train Epoch 0 Progress: 16.53%	Loss: 1.4905
# Train Epoch 0 Progress: 17.07%	Loss: 1.3344
# Train Epoch 0 Progress: 17.6%	Loss: 1.5252
# Train Epoch 0 Progress: 18.13%	Loss: 1.1998
# Train Epoch 0 Progress: 18.67%	Loss: 1.3895
# Train Epoch 0 Progress: 19.2%	Loss: 1.2826
# Train Epoch 0 Progress: 19.73%	Loss: 1.1084
# Train Epoch 0 Progress: 20.27%	Loss: 0.971
# Train Epoch 0 Progress: 20.8%	Loss: 0.8519
# Train Epoch 0 Progress: 21.33%	Loss: 1.1486
# Train Epoch 0 Progress: 21.87%	Loss: 0.8762
# Train Epoch 0 Progress: 22.4%	Loss: 0.9253
# Train Epoch 0 Progress: 22.93%	Loss: 1.0468
# Train Epoch 0 Progress: 23.47%	Loss: 0.9815
# Train Epoch 0 Progress: 24.0%	Loss: 0.8268
# Train Epoch 0 Progress: 24.53%	Loss: 0.8352
# Train Epoch 0 Progress: 25.07%	Loss: 0.4511
# Train Epoch 0 Progress: 25.6%	Loss: 0.7712
# Train Epoch 0 Progress: 26.13%	Loss: 0.5856
# Train Epoch 0 Progress: 26.67%	Loss: 0.7555
# Train Epoch 0 Progress: 27.2%	Loss: 0.4972
# Train Epoch 0 Progress: 27.73%	Loss: 0.7422
# Train Epoch 0 Progress: 28.27%	Loss: 0.8906
# Train Epoch 0 Progress: 28.8%	Loss: 1.0185
# Train Epoch 0 Progress: 29.33%	Loss: 1.0167
# Train Epoch 0 Progress: 29.87%	Loss: 1.2887
# Train Epoch 0 Progress: 30.4%	Loss: 0.6919
# Train Epoch 0 Progress: 30.93%	Loss: 0.5256
# Train Epoch 0 Progress: 31.47%	Loss: 0.8348
# Train Epoch 0 Progress: 32.0%	Loss: 1.0093
# Train Epoch 0 Progress: 32.53%	Loss: 0.7048
# Train Epoch 0 Progress: 33.07%	Loss: 0.7132
# Train Epoch 0 Progress: 33.6%	Loss: 0.4293
# Train Epoch 0 Progress: 34.13%	Loss: 0.7672
# Train Epoch 0 Progress: 34.67%	Loss: 0.7949
# Train Epoch 0 Progress: 35.2%	Loss: 0.7839
# Train Epoch 0 Progress: 35.73%	Loss: 0.8241
# Train Epoch 0 Progress: 36.27%	Loss: 0.7085
# Train Epoch 0 Progress: 36.8%	Loss: 0.6723
# Train Epoch 0 Progress: 37.33%	Loss: 0.7129
# Train Epoch 0 Progress: 37.87%	Loss: 0.6225
# Train Epoch 0 Progress: 38.4%	Loss: 0.8033
# Train Epoch 0 Progress: 38.93%	Loss: 0.577
# Train Epoch 0 Progress: 39.47%	Loss: 0.7597
# Train Epoch 0 Progress: 40.0%	Loss: 0.5544
# Train Epoch 0 Progress: 40.53%	Loss: 0.6398
# Train Epoch 0 Progress: 41.07%	Loss: 1.0785
# Train Epoch 0 Progress: 41.6%	Loss: 0.7242
# Train Epoch 0 Progress: 42.13%	Loss: 0.6774
# Train Epoch 0 Progress: 42.67%	Loss: 0.4319
# Train Epoch 0 Progress: 43.2%	Loss: 0.6343
# Train Epoch 0 Progress: 43.73%	Loss: 0.7703
# Train Epoch 0 Progress: 44.27%	Loss: 0.6388
# Train Epoch 0 Progress: 44.8%	Loss: 0.4529
# Train Epoch 0 Progress: 45.33%	Loss: 1.1542
# Train Epoch 0 Progress: 45.87%	Loss: 0.7578
# Train Epoch 0 Progress: 46.4%	Loss: 0.451
# Train Epoch 0 Progress: 46.93%	Loss: 0.3763
# Train Epoch 0 Progress: 47.47%	Loss: 0.4564
# Train Epoch 0 Progress: 48.0%	Loss: 0.5336
# Train Epoch 0 Progress: 48.53%	Loss: 0.4801
# Train Epoch 0 Progress: 49.07%	Loss: 0.5862
# Train Epoch 0 Progress: 49.6%	Loss: 0.5212
# Train Epoch 0 Progress: 50.13%	Loss: 0.5898
# Train Epoch 0 Progress: 50.67%	Loss: 0.4684
# Train Epoch 0 Progress: 51.2%	Loss: 0.6502
# Train Epoch 0 Progress: 51.73%	Loss: 0.2817
# Train Epoch 0 Progress: 52.27%	Loss: 0.5902
# Train Epoch 0 Progress: 52.8%	Loss: 0.3972
# Train Epoch 0 Progress: 53.33%	Loss: 0.5128
# Train Epoch 0 Progress: 53.87%	Loss: 0.509
# Train Epoch 0 Progress: 54.4%	Loss: 0.4353
# Train Epoch 0 Progress: 54.93%	Loss: 0.44
# Train Epoch 0 Progress: 55.47%	Loss: 0.434
# Train Epoch 0 Progress: 56.0%	Loss: 0.446
# Train Epoch 0 Progress: 56.53%	Loss: 1.117
# Train Epoch 0 Progress: 57.07%	Loss: 0.3011
# Train Epoch 0 Progress: 57.6%	Loss: 0.2507
# Train Epoch 0 Progress: 58.13%	Loss: 0.5167
# Train Epoch 0 Progress: 58.67%	Loss: 0.1586
# Train Epoch 0 Progress: 59.2%	Loss: 0.7732
# Train Epoch 0 Progress: 59.73%	Loss: 0.529
# Train Epoch 0 Progress: 60.27%	Loss: 0.7259
# Train Epoch 0 Progress: 60.8%	Loss: 0.2578
# Train Epoch 0 Progress: 61.33%	Loss: 0.4768
# Train Epoch 0 Progress: 61.87%	Loss: 0.5166
# Train Epoch 0 Progress: 62.4%	Loss: 0.4637
# Train Epoch 0 Progress: 62.93%	Loss: 0.5402
# Train Epoch 0 Progress: 63.47%	Loss: 0.6409
# Train Epoch 0 Progress: 64.0%	Loss: 0.2801
# Train Epoch 0 Progress: 64.53%	Loss: 0.5917
# Train Epoch 0 Progress: 65.07%	Loss: 0.6677
# Train Epoch 0 Progress: 65.6%	Loss: 0.4659
# Train Epoch 0 Progress: 66.13%	Loss: 0.5907
# Train Epoch 0 Progress: 66.67%	Loss: 0.9188
# Train Epoch 0 Progress: 67.2%	Loss: 0.2081
# Train Epoch 0 Progress: 67.73%	Loss: 0.4315
# Train Epoch 0 Progress: 68.27%	Loss: 0.3905
# Train Epoch 0 Progress: 68.8%	Loss: 0.3323
# Train Epoch 0 Progress: 69.33%	Loss: 0.1805
# Train Epoch 0 Progress: 69.87%	Loss: 0.4287
# Train Epoch 0 Progress: 70.4%	Loss: 0.5591
# Train Epoch 0 Progress: 70.93%	Loss: 0.6309
# Train Epoch 0 Progress: 71.47%	Loss: 0.4613
# Train Epoch 0 Progress: 72.0%	Loss: 0.2737
# Train Epoch 0 Progress: 72.53%	Loss: 0.1312
# Train Epoch 0 Progress: 73.07%	Loss: 0.547
# Train Epoch 0 Progress: 73.6%	Loss: 0.1547
# Train Epoch 0 Progress: 74.13%	Loss: 0.2883
# Train Epoch 0 Progress: 74.67%	Loss: 0.2857
# Train Epoch 0 Progress: 75.2%	Loss: 0.4222
# Train Epoch 0 Progress: 75.73%	Loss: 0.3482
# Train Epoch 0 Progress: 76.27%	Loss: 0.3687
# Train Epoch 0 Progress: 76.8%	Loss: 0.431
# Train Epoch 0 Progress: 77.33%	Loss: 0.3189
# Train Epoch 0 Progress: 77.87%	Loss: 0.3128
# Train Epoch 0 Progress: 78.4%	Loss: 0.1676
# Train Epoch 0 Progress: 78.93%	Loss: 0.6136
# Train Epoch 0 Progress: 79.47%	Loss: 0.325
# Train Epoch 0 Progress: 80.0%	Loss: 0.5943
# Train Epoch 0 Progress: 80.53%	Loss: 0.6242
# Train Epoch 0 Progress: 81.07%	Loss: 0.2794
# Train Epoch 0 Progress: 81.6%	Loss: 0.2415
# Train Epoch 0 Progress: 82.13%	Loss: 0.4575
# Train Epoch 0 Progress: 82.67%	Loss: 0.4498
# Train Epoch 0 Progress: 83.2%	Loss: 0.7998
# Train Epoch 0 Progress: 83.73%	Loss: 0.5056
# Train Epoch 0 Progress: 84.27%	Loss: 0.426
# Train Epoch 0 Progress: 84.8%	Loss: 0.3182
# Train Epoch 0 Progress: 85.33%	Loss: 0.5716
# Train Epoch 0 Progress: 85.87%	Loss: 0.5121
# Train Epoch 0 Progress: 86.4%	Loss: 1.0797
# Train Epoch 0 Progress: 86.93%	Loss: 0.3989
# Train Epoch 0 Progress: 87.47%	Loss: 0.5807
# Train Epoch 0 Progress: 88.0%	Loss: 0.4049
# Train Epoch 0 Progress: 88.53%	Loss: 0.2884
# Train Epoch 0 Progress: 89.07%	Loss: 0.3008
# Train Epoch 0 Progress: 89.6%	Loss: 0.616
# Train Epoch 0 Progress: 90.13%	Loss: 0.4088
# Train Epoch 0 Progress: 90.67%	Loss: 0.5132
# Train Epoch 0 Progress: 91.2%	Loss: 0.7775
# Train Epoch 0 Progress: 91.73%	Loss: 0.5288
# Train Epoch 0 Progress: 92.27%	Loss: 0.4633
# Train Epoch 0 Progress: 92.8%	Loss: 0.4134
# Train Epoch 0 Progress: 93.33%	Loss: 0.319
# Train Epoch 0 Progress: 93.87%	Loss: 0.5107
# Train Epoch 0 Progress: 94.4%	Loss: 0.239
# Train Epoch 0 Progress: 94.93%	Loss: 0.2236
# Train Epoch 0 Progress: 95.47%	Loss: 0.4745
# Train Epoch 0 Progress: 96.0%	Loss: 0.3353
# Train Epoch 0 Progress: 96.53%	Loss: 0.4284
# Train Epoch 0 Progress: 97.07%	Loss: 0.4378
# Train Epoch 0 Progress: 97.6%	Loss: 0.3879
# Train Epoch 0 Progress: 98.13%	Loss: 0.2582
# Train Epoch 0 Progress: 98.67%	Loss: 0.3304
# Train Epoch 0 Progress: 99.2%	Loss: 0.3358
# Train Epoch 0 Progress: 99.73%	Loss: 0.5622
#
# Test set: Avg loss 0.159, Accuracy 95.27%
#
# Train Epoch 1 Progress: 0.0%	Loss: 0.2832
# Train Epoch 1 Progress: 0.53%	Loss: 0.7545
# Train Epoch 1 Progress: 1.07%	Loss: 0.195
# Train Epoch 1 Progress: 1.6%	Loss: 0.355
# Train Epoch 1 Progress: 2.13%	Loss: 0.6323
# Train Epoch 1 Progress: 2.67%	Loss: 0.1696
# Train Epoch 1 Progress: 3.2%	Loss: 0.4316
# Train Epoch 1 Progress: 3.73%	Loss: 0.2353
# Train Epoch 1 Progress: 4.27%	Loss: 0.2167
# Train Epoch 1 Progress: 4.8%	Loss: 0.5109
# Train Epoch 1 Progress: 5.33%	Loss: 0.4381
# Train Epoch 1 Progress: 5.87%	Loss: 0.3973
# Train Epoch 1 Progress: 6.4%	Loss: 0.6099
# Train Epoch 1 Progress: 6.93%	Loss: 0.3494
# Train Epoch 1 Progress: 7.47%	Loss: 0.2535
# Train Epoch 1 Progress: 8.0%	Loss: 0.5376
# Train Epoch 1 Progress: 8.53%	Loss: 0.3333
# Train Epoch 1 Progress: 9.07%	Loss: 0.1695
# Train Epoch 1 Progress: 9.6%	Loss: 0.1142
# Train Epoch 1 Progress: 10.13%	Loss: 0.4388
# Train Epoch 1 Progress: 10.67%	Loss: 0.2409
# Train Epoch 1 Progress: 11.2%	Loss: 0.2784
# Train Epoch 1 Progress: 11.73%	Loss: 0.2619
# Train Epoch 1 Progress: 12.27%	Loss: 0.2616
# Train Epoch 1 Progress: 12.8%	Loss: 0.3415
# Train Epoch 1 Progress: 13.33%	Loss: 0.4169
# Train Epoch 1 Progress: 13.87%	Loss: 0.2847
# Train Epoch 1 Progress: 14.4%	Loss: 0.4721
# Train Epoch 1 Progress: 14.93%	Loss: 0.3339
# Train Epoch 1 Progress: 15.47%	Loss: 0.5343
# Train Epoch 1 Progress: 16.0%	Loss: 0.41
# Train Epoch 1 Progress: 16.53%	Loss: 0.863
# Train Epoch 1 Progress: 17.07%	Loss: 0.2567
# Train Epoch 1 Progress: 17.6%	Loss: 0.4231
# Train Epoch 1 Progress: 18.13%	Loss: 0.7829
# Train Epoch 1 Progress: 18.67%	Loss: 0.3436
# Train Epoch 1 Progress: 19.2%	Loss: 0.3209
# Train Epoch 1 Progress: 19.73%	Loss: 0.3115
# Train Epoch 1 Progress: 20.27%	Loss: 0.5336
# Train Epoch 1 Progress: 20.8%	Loss: 0.3367
# Train Epoch 1 Progress: 21.33%	Loss: 0.5672
# Train Epoch 1 Progress: 21.87%	Loss: 0.7659
# Train Epoch 1 Progress: 22.4%	Loss: 0.4511
# Train Epoch 1 Progress: 22.93%	Loss: 0.2352
# Train Epoch 1 Progress: 23.47%	Loss: 0.3607
# Train Epoch 1 Progress: 24.0%	Loss: 0.6607
# Train Epoch 1 Progress: 24.53%	Loss: 0.2806
# Train Epoch 1 Progress: 25.07%	Loss: 0.3132
# Train Epoch 1 Progress: 25.6%	Loss: 0.2393
# Train Epoch 1 Progress: 26.13%	Loss: 0.4681
# Train Epoch 1 Progress: 26.67%	Loss: 0.3904
# Train Epoch 1 Progress: 27.2%	Loss: 0.5505
# Train Epoch 1 Progress: 27.73%	Loss: 0.3451
# Train Epoch 1 Progress: 28.27%	Loss: 0.4692
# Train Epoch 1 Progress: 28.8%	Loss: 0.4645
# Train Epoch 1 Progress: 29.33%	Loss: 0.4747
# Train Epoch 1 Progress: 29.87%	Loss: 0.419
# Train Epoch 1 Progress: 30.4%	Loss: 0.3536
# Train Epoch 1 Progress: 30.93%	Loss: 0.1527
# Train Epoch 1 Progress: 31.47%	Loss: 0.5698
# Train Epoch 1 Progress: 32.0%	Loss: 0.2794
# Train Epoch 1 Progress: 32.53%	Loss: 0.2284
# Train Epoch 1 Progress: 33.07%	Loss: 0.1178
# Train Epoch 1 Progress: 33.6%	Loss: 0.2974
# Train Epoch 1 Progress: 34.13%	Loss: 0.278
# Train Epoch 1 Progress: 34.67%	Loss: 0.169
# Train Epoch 1 Progress: 35.2%	Loss: 0.2193
# Train Epoch 1 Progress: 35.73%	Loss: 0.9597
# Train Epoch 1 Progress: 36.27%	Loss: 0.319
# Train Epoch 1 Progress: 36.8%	Loss: 0.6496
# Train Epoch 1 Progress: 37.33%	Loss: 0.1986
# Train Epoch 1 Progress: 37.87%	Loss: 0.6319
# Train Epoch 1 Progress: 38.4%	Loss: 0.3121
# Train Epoch 1 Progress: 38.93%	Loss: 0.1872
# Train Epoch 1 Progress: 39.47%	Loss: 0.4516
# Train Epoch 1 Progress: 40.0%	Loss: 0.5732
# Train Epoch 1 Progress: 40.53%	Loss: 0.3121
# Train Epoch 1 Progress: 41.07%	Loss: 0.7336
# Train Epoch 1 Progress: 41.6%	Loss: 0.3715
# Train Epoch 1 Progress: 42.13%	Loss: 0.3036
# Train Epoch 1 Progress: 42.67%	Loss: 0.1905
# Train Epoch 1 Progress: 43.2%	Loss: 0.3864
# Train Epoch 1 Progress: 43.73%	Loss: 0.2519
# Train Epoch 1 Progress: 44.27%	Loss: 0.2319
# Train Epoch 1 Progress: 44.8%	Loss: 0.3511
# Train Epoch 1 Progress: 45.33%	Loss: 0.4652
# Train Epoch 1 Progress: 45.87%	Loss: 0.2399
# Train Epoch 1 Progress: 46.4%	Loss: 0.2928
# Train Epoch 1 Progress: 46.93%	Loss: 0.4845
# Train Epoch 1 Progress: 47.47%	Loss: 0.4592
# Train Epoch 1 Progress: 48.0%	Loss: 0.3821
# Train Epoch 1 Progress: 48.53%	Loss: 0.3171
# Train Epoch 1 Progress: 49.07%	Loss: 0.2801
# Train Epoch 1 Progress: 49.6%	Loss: 0.4302
# Train Epoch 1 Progress: 50.13%	Loss: 0.3105
# Train Epoch 1 Progress: 50.67%	Loss: 0.305
# Train Epoch 1 Progress: 51.2%	Loss: 0.2904
# Train Epoch 1 Progress: 51.73%	Loss: 0.3066
# Train Epoch 1 Progress: 52.27%	Loss: 0.5823
# Train Epoch 1 Progress: 52.8%	Loss: 0.269
# Train Epoch 1 Progress: 53.33%	Loss: 0.1766
# Train Epoch 1 Progress: 53.87%	Loss: 0.2673
# Train Epoch 1 Progress: 54.4%	Loss: 0.153
# Train Epoch 1 Progress: 54.93%	Loss: 0.3141
# Train Epoch 1 Progress: 55.47%	Loss: 0.4148
# Train Epoch 1 Progress: 56.0%	Loss: 0.2277
# Train Epoch 1 Progress: 56.53%	Loss: 0.4655
# Train Epoch 1 Progress: 57.07%	Loss: 0.3024
# Train Epoch 1 Progress: 57.6%	Loss: 0.1886
# Train Epoch 1 Progress: 58.13%	Loss: 0.3264
# Train Epoch 1 Progress: 58.67%	Loss: 0.7999
# Train Epoch 1 Progress: 59.2%	Loss: 0.2483
# Train Epoch 1 Progress: 59.73%	Loss: 0.4869
# Train Epoch 1 Progress: 60.27%	Loss: 0.3106
# Train Epoch 1 Progress: 60.8%	Loss: 0.2524
# Train Epoch 1 Progress: 61.33%	Loss: 0.1894
# Train Epoch 1 Progress: 61.87%	Loss: 0.4261
# Train Epoch 1 Progress: 62.4%	Loss: 0.1531
# Train Epoch 1 Progress: 62.93%	Loss: 0.2478
# Train Epoch 1 Progress: 63.47%	Loss: 0.1921
# Train Epoch 1 Progress: 64.0%	Loss: 0.3766
# Train Epoch 1 Progress: 64.53%	Loss: 0.2622
# Train Epoch 1 Progress: 65.07%	Loss: 0.1848
# Train Epoch 1 Progress: 65.6%	Loss: 0.2752
# Train Epoch 1 Progress: 66.13%	Loss: 0.6379
# Train Epoch 1 Progress: 66.67%	Loss: 0.3315
# Train Epoch 1 Progress: 67.2%	Loss: 0.5158
# Train Epoch 1 Progress: 67.73%	Loss: 0.3708
# Train Epoch 1 Progress: 68.27%	Loss: 0.4721
# Train Epoch 1 Progress: 68.8%	Loss: 0.3717
# Train Epoch 1 Progress: 69.33%	Loss: 0.2106
# Train Epoch 1 Progress: 69.87%	Loss: 0.4173
# Train Epoch 1 Progress: 70.4%	Loss: 0.3864
# Train Epoch 1 Progress: 70.93%	Loss: 0.1504
# Train Epoch 1 Progress: 71.47%	Loss: 0.0599
# Train Epoch 1 Progress: 72.0%	Loss: 0.2359
# Train Epoch 1 Progress: 72.53%	Loss: 0.2514
# Train Epoch 1 Progress: 73.07%	Loss: 0.435
# Train Epoch 1 Progress: 73.6%	Loss: 0.1885
# Train Epoch 1 Progress: 74.13%	Loss: 0.1548
# Train Epoch 1 Progress: 74.67%	Loss: 0.3034
# Train Epoch 1 Progress: 75.2%	Loss: 0.2227
# Train Epoch 1 Progress: 75.73%	Loss: 0.5782
# Train Epoch 1 Progress: 76.27%	Loss: 0.2785
# Train Epoch 1 Progress: 76.8%	Loss: 0.0701
# Train Epoch 1 Progress: 77.33%	Loss: 0.6893
# Train Epoch 1 Progress: 77.87%	Loss: 0.4488
# Train Epoch 1 Progress: 78.4%	Loss: 0.2349
# Train Epoch 1 Progress: 78.93%	Loss: 0.2061
# Train Epoch 1 Progress: 79.47%	Loss: 0.5202
# Train Epoch 1 Progress: 80.0%	Loss: 0.3099
# Train Epoch 1 Progress: 80.53%	Loss: 0.1649
# Train Epoch 1 Progress: 81.07%	Loss: 0.5511
# Train Epoch 1 Progress: 81.6%	Loss: 0.2605
# Train Epoch 1 Progress: 82.13%	Loss: 0.1996
# Train Epoch 1 Progress: 82.67%	Loss: 0.4636
# Train Epoch 1 Progress: 83.2%	Loss: 0.1284
# Train Epoch 1 Progress: 83.73%	Loss: 0.2862
# Train Epoch 1 Progress: 84.27%	Loss: 0.3772
# Train Epoch 1 Progress: 84.8%	Loss: 0.8737
# Train Epoch 1 Progress: 85.33%	Loss: 0.2786
# Train Epoch 1 Progress: 85.87%	Loss: 0.1371
# Train Epoch 1 Progress: 86.4%	Loss: 0.192
# Train Epoch 1 Progress: 86.93%	Loss: 0.6835
# Train Epoch 1 Progress: 87.47%	Loss: 0.4556
# Train Epoch 1 Progress: 88.0%	Loss: 0.4047
# Train Epoch 1 Progress: 88.53%	Loss: 0.2575
# Train Epoch 1 Progress: 89.07%	Loss: 0.3479
# Train Epoch 1 Progress: 89.6%	Loss: 0.2495
# Train Epoch 1 Progress: 90.13%	Loss: 0.2094
# Train Epoch 1 Progress: 90.67%	Loss: 0.3053
# Train Epoch 1 Progress: 91.2%	Loss: 0.122
# Train Epoch 1 Progress: 91.73%	Loss: 0.4761
# Train Epoch 1 Progress: 92.27%	Loss: 0.218
# Train Epoch 1 Progress: 92.8%	Loss: 0.304
# Train Epoch 1 Progress: 93.33%	Loss: 0.1131
# Train Epoch 1 Progress: 93.87%	Loss: 0.3014
# Train Epoch 1 Progress: 94.4%	Loss: 0.2776
# Train Epoch 1 Progress: 94.93%	Loss: 0.1727
# Train Epoch 1 Progress: 95.47%	Loss: 0.7518
# Train Epoch 1 Progress: 96.0%	Loss: 0.3678
# Train Epoch 1 Progress: 96.53%	Loss: 0.6715
# Train Epoch 1 Progress: 97.07%	Loss: 0.14
# Train Epoch 1 Progress: 97.6%	Loss: 0.2726
# Train Epoch 1 Progress: 98.13%	Loss: 0.1936
# Train Epoch 1 Progress: 98.67%	Loss: 0.4579
# Train Epoch 1 Progress: 99.2%	Loss: 0.241
# Train Epoch 1 Progress: 99.73%	Loss: 0.7104
#
# Test set: Avg loss 0.1102, Accuracy 96.54%
#
# Training with lr=0.001, momentum=0.9, batch_size=64
#
# Test set: Avg loss 2.3157, Accuracy 10.23%
#
# Train Epoch 0 Progress: 0.0%	Loss: 2.3418
# Train Epoch 0 Progress: 1.07%	Loss: 2.3057
# Train Epoch 0 Progress: 2.13%	Loss: 2.3018
# Train Epoch 0 Progress: 3.2%	Loss: 2.3007
# Train Epoch 0 Progress: 4.27%	Loss: 2.2539
# Train Epoch 0 Progress: 5.33%	Loss: 2.3132
# Train Epoch 0 Progress: 6.4%	Loss: 2.3158
# Train Epoch 0 Progress: 7.47%	Loss: 2.2672
# Train Epoch 0 Progress: 8.53%	Loss: 2.2752
# Train Epoch 0 Progress: 9.6%	Loss: 2.2206
# Train Epoch 0 Progress: 10.67%	Loss: 2.2793
# Train Epoch 0 Progress: 11.73%	Loss: 2.1904
# Train Epoch 0 Progress: 12.8%	Loss: 2.1794
# Train Epoch 0 Progress: 13.87%	Loss: 2.1544
# Train Epoch 0 Progress: 14.93%	Loss: 2.1289
# Train Epoch 0 Progress: 16.0%	Loss: 2.1171
# Train Epoch 0 Progress: 17.07%	Loss: 2.0662
# Train Epoch 0 Progress: 18.13%	Loss: 2.0534
# Train Epoch 0 Progress: 19.2%	Loss: 1.9693
# Train Epoch 0 Progress: 20.27%	Loss: 2.0567
# Train Epoch 0 Progress: 21.33%	Loss: 1.8031
# Train Epoch 0 Progress: 22.4%	Loss: 1.8139
# Train Epoch 0 Progress: 23.47%	Loss: 1.8729
# Train Epoch 0 Progress: 24.53%	Loss: 1.6699
# Train Epoch 0 Progress: 25.6%	Loss: 1.6427
# Train Epoch 0 Progress: 26.67%	Loss: 1.586
# Train Epoch 0 Progress: 27.73%	Loss: 1.5627
# Train Epoch 0 Progress: 28.8%	Loss: 1.6777
# Train Epoch 0 Progress: 29.87%	Loss: 1.3965
# Train Epoch 0 Progress: 30.93%	Loss: 1.4749
# Train Epoch 0 Progress: 32.0%	Loss: 1.3982
# Train Epoch 0 Progress: 33.07%	Loss: 1.2449
# Train Epoch 0 Progress: 34.13%	Loss: 1.501
# Train Epoch 0 Progress: 35.2%	Loss: 1.6511
# Train Epoch 0 Progress: 36.27%	Loss: 1.347
# Train Epoch 0 Progress: 37.33%	Loss: 1.2491
# Train Epoch 0 Progress: 38.4%	Loss: 1.1862
# Train Epoch 0 Progress: 39.47%	Loss: 1.0843
# Train Epoch 0 Progress: 40.53%	Loss: 1.2111
# Train Epoch 0 Progress: 41.6%	Loss: 1.0418
# Train Epoch 0 Progress: 42.67%	Loss: 1.2567
# Train Epoch 0 Progress: 43.73%	Loss: 1.2264
# Train Epoch 0 Progress: 44.8%	Loss: 1.0302
# Train Epoch 0 Progress: 45.87%	Loss: 1.2288
# Train Epoch 0 Progress: 46.93%	Loss: 1.0824
# Train Epoch 0 Progress: 48.0%	Loss: 1.0713
# Train Epoch 0 Progress: 49.07%	Loss: 1.0517
# Train Epoch 0 Progress: 50.13%	Loss: 0.9429
# Train Epoch 0 Progress: 51.2%	Loss: 0.8986
# Train Epoch 0 Progress: 52.27%	Loss: 0.9258
# Train Epoch 0 Progress: 53.33%	Loss: 0.9601
# ...
# Train Epoch 1 Progress: 59.73%	Loss: 2.2854
# Train Epoch 1 Progress: 60.27%	Loss: 2.3437
# Train Epoch 1 Progress: 60.8%	Loss: 2.3072
# Train Epoch 1 Progress: 61.33%	Loss: 2.2943
# Train Epoch 1 Progress: 61.87%	Loss: 2.2833
# Train Epoch 1 Progress: 62.4%	Loss: 2.3056
# Train Epoch 1 Progress: 62.93%	Loss: 2.2898
# Train Epoch 1 Progress: 63.47%	Loss: 2.2429
# Train Epoch 1 Progress: 64.0%	Loss: 2.3185
# Train Epoch 1 Progress: 64.53%	Loss: 2.3104
# Train Epoch 1 Progress: 65.07%	Loss: 2.3713
# Train Epoch 1 Progress: 65.6%	Loss: 2.3198
# Train Epoch 1 Progress: 66.13%	Loss: 2.285
# Train Epoch 1 Progress: 66.67%	Loss: 2.3143
# Train Epoch 1 Progress: 67.2%	Loss: 2.3197
# Train Epoch 1 Progress: 67.73%	Loss: 2.2918
# Train Epoch 1 Progress: 68.27%	Loss: 2.3047
# Train Epoch 1 Progress: 68.8%	Loss: 2.3466
# Train Epoch 1 Progress: 69.33%	Loss: 2.2562
# Train Epoch 1 Progress: 69.87%	Loss: 2.3416
# Train Epoch 1 Progress: 70.4%	Loss: 2.3239
# Train Epoch 1 Progress: 70.93%	Loss: 2.324
# Train Epoch 1 Progress: 71.47%	Loss: 2.279
# Train Epoch 1 Progress: 72.0%	Loss: 2.3431
# Train Epoch 1 Progress: 72.53%	Loss: 2.3194
# Train Epoch 1 Progress: 73.07%	Loss: 2.3253
# Train Epoch 1 Progress: 73.6%	Loss: 2.3008
# Train Epoch 1 Progress: 74.13%	Loss: 2.3168
# Train Epoch 1 Progress: 74.67%	Loss: 2.3012
# Train Epoch 1 Progress: 75.2%	Loss: 2.2817
# Train Epoch 1 Progress: 75.73%	Loss: 2.3044
# Train Epoch 1 Progress: 76.27%	Loss: 2.3221
# Train Epoch 1 Progress: 76.8%	Loss: 2.3026
# Train Epoch 1 Progress: 77.33%	Loss: 2.2768
# Train Epoch 1 Progress: 77.87%	Loss: 2.2807
# Train Epoch 1 Progress: 78.4%	Loss: 2.3038
# Train Epoch 1 Progress: 78.93%	Loss: 2.2961
# Train Epoch 1 Progress: 79.47%	Loss: 2.3266
# Train Epoch 1 Progress: 80.0%	Loss: 2.3094
# Train Epoch 1 Progress: 80.53%	Loss: 2.3213
# Train Epoch 1 Progress: 81.07%	Loss: 2.2708
# Train Epoch 1 Progress: 81.6%	Loss: 2.3415
# Train Epoch 1 Progress: 82.13%	Loss: 2.3059
# Train Epoch 1 Progress: 82.67%	Loss: 2.3416
# Train Epoch 1 Progress: 83.2%	Loss: 2.2977
# Train Epoch 1 Progress: 83.73%	Loss: 2.2971
# Train Epoch 1 Progress: 84.27%	Loss: 2.3248
# Train Epoch 1 Progress: 84.8%	Loss: 2.3084
# Train Epoch 1 Progress: 85.33%	Loss: 2.2936
# Train Epoch 1 Progress: 85.87%	Loss: 2.3282
# Train Epoch 1 Progress: 86.4%	Loss: 2.3292
# Train Epoch 1 Progress: 86.93%	Loss: 2.2863
# Train Epoch 1 Progress: 87.47%	Loss: 2.2898
# Train Epoch 1 Progress: 88.0%	Loss: 2.3122
# Train Epoch 1 Progress: 88.53%	Loss: 2.2912
# Train Epoch 1 Progress: 89.07%	Loss: 2.36
# Train Epoch 1 Progress: 89.6%	Loss: 2.3131
# Train Epoch 1 Progress: 90.13%	Loss: 2.2961
# Train Epoch 1 Progress: 90.67%	Loss: 2.315
# Train Epoch 1 Progress: 91.2%	Loss: 2.2832
# Train Epoch 1 Progress: 91.73%	Loss: 2.3178
# Train Epoch 1 Progress: 92.27%	Loss: 2.3172
# Train Epoch 1 Progress: 92.8%	Loss: 2.2973
# Train Epoch 1 Progress: 93.33%	Loss: 2.2894
# Train Epoch 1 Progress: 93.87%	Loss: 2.3169
# Train Epoch 1 Progress: 94.4%	Loss: 2.3195
# Train Epoch 1 Progress: 94.93%	Loss: 2.303
# Train Epoch 1 Progress: 95.47%	Loss: 2.3217
# Train Epoch 1 Progress: 96.0%	Loss: 2.2831
# Train Epoch 1 Progress: 96.53%	Loss: 2.3001
# Train Epoch 1 Progress: 97.07%	Loss: 2.3259
# Train Epoch 1 Progress: 97.6%	Loss: 2.3138
# Train Epoch 1 Progress: 98.13%	Loss: 2.3157
# Train Epoch 1 Progress: 98.67%	Loss: 2.2905
# Train Epoch 1 Progress: 99.2%	Loss: 2.3104
# Train Epoch 1 Progress: 99.73%	Loss: 2.2535
#
# Test set: Avg loss 2.3091, Accuracy 10.1%
#
# Training with lr=0.1, momentum=0.9, batch_size=64
#
# Test set: Avg loss 2.3142, Accuracy 14.4%
#
# Train Epoch 0 Progress: 0.0%	Loss: 2.287
# Train Epoch 0 Progress: 1.07%	Loss: 2.1163
# Train Epoch 0 Progress: 2.13%	Loss: 1.783
# Train Epoch 0 Progress: 3.2%	Loss: 1.6603
# Train Epoch 0 Progress: 4.27%	Loss: 1.1357
# Train Epoch 0 Progress: 5.33%	Loss: 1.6503
# Train Epoch 0 Progress: 6.4%	Loss: 1.5226
# Train Epoch 0 Progress: 7.47%	Loss: 2.1415
# Train Epoch 0 Progress: 8.53%	Loss: 2.0149
# Train Epoch 0 Progress: 9.6%	Loss: 2.2235
# Train Epoch 0 Progress: 10.67%	Loss: 2.5983
# Train Epoch 0 Progress: 11.73%	Loss: 2.2988
# Train Epoch 0 Progress: 12.8%	Loss: 2.2758
# Train Epoch 0 Progress: 13.87%	Loss: 2.3276
# Train Epoch 0 Progress: 14.93%	Loss: 2.2894
# Train Epoch 0 Progress: 16.0%	Loss: 2.297
# Train Epoch 0 Progress: 17.07%	Loss: 2.2915
# Train Epoch 0 Progress: 18.13%	Loss: 2.26
# Train Epoch 0 Progress: 19.2%	Loss: 2.3166
# Train Epoch 0 Progress: 20.27%	Loss: 2.3002
# Train Epoch 0 Progress: 21.33%	Loss: 2.3268
# Train Epoch 0 Progress: 22.4%	Loss: 2.3037
# Train Epoch 0 Progress: 23.47%	Loss: 2.3142
# Train Epoch 0 Progress: 24.53%	Loss: 2.2983
# Train Epoch 0 Progress: 25.6%	Loss: 2.2991
# Train Epoch 0 Progress: 26.67%	Loss: 2.316
# Train Epoch 0 Progress: 27.73%	Loss: 2.3285
# Train Epoch 0 Progress: 28.8%	Loss: 2.3164
# Train Epoch 0 Progress: 29.87%	Loss: 2.2759
# Train Epoch 0 Progress: 30.93%	Loss: 2.3047
# Train Epoch 0 Progress: 32.0%	Loss: 2.2945
# Train Epoch 0 Progress: 33.07%	Loss: 2.3192
# Train Epoch 0 Progress: 34.13%	Loss: 2.3102
# Train Epoch 0 Progress: 35.2%	Loss: 2.3008
# Train Epoch 0 Progress: 36.27%	Loss: 2.3026
# Train Epoch 0 Progress: 37.33%	Loss: 2.3114
# Train Epoch 0 Progress: 38.4%	Loss: 2.2975
# Train Epoch 0 Progress: 39.47%	Loss: 2.2939
# Train Epoch 0 Progress: 40.53%	Loss: 2.2868
# Train Epoch 0 Progress: 41.6%	Loss: 2.2955
# Train Epoch 0 Progress: 42.67%	Loss: 2.3082
# Train Epoch 0 Progress: 43.73%	Loss: 2.2777
# Train Epoch 0 Progress: 44.8%	Loss: 2.2773
# Train Epoch 0 Progress: 45.87%	Loss: 2.3062
# Train Epoch 0 Progress: 46.93%	Loss: 2.3028
# Train Epoch 0 Progress: 48.0%	Loss: 2.3124
# Train Epoch 0 Progress: 49.07%	Loss: 2.2977
# Train Epoch 0 Progress: 50.13%	Loss: 2.312
# Train Epoch 0 Progress: 51.2%	Loss: 2.2947
# Train Epoch 0 Progress: 52.27%	Loss: 2.3249
# Train Epoch 0 Progress: 53.33%	Loss: 2.3173
# Train Epoch 0 Progress: 54.4%	Loss: 2.3142
# Train Epoch 0 Progress: 55.47%	Loss: 2.3183
# Train Epoch 0 Progress: 56.53%	Loss: 2.2976
# Train Epoch 0 Progress: 57.6%	Loss: 2.3254
# Train Epoch 0 Progress: 58.67%	Loss: 2.2973
# Train Epoch 0 Progress: 59.73%	Loss: 2.2948
# Train Epoch 0 Progress: 60.8%	Loss: 2.2986
# Train Epoch 0 Progress: 61.87%	Loss: 2.3025
# Train Epoch 0 Progress: 62.93%	Loss: 2.3222
# Train Epoch 0 Progress: 64.0%	Loss: 2.3193
# Train Epoch 0 Progress: 65.07%	Loss: 2.3085
# Train Epoch 0 Progress: 66.13%	Loss: 2.2948
# Train Epoch 0 Progress: 67.2%	Loss: 2.3077
# Train Epoch 0 Progress: 68.27%	Loss: 2.2928
# Train Epoch 0 Progress: 69.33%	Loss: 2.3223
# Train Epoch 0 Progress: 70.4%	Loss: 2.289
# Train Epoch 0 Progress: 71.47%	Loss: 2.2931
# Train Epoch 0 Progress: 72.53%	Loss: 2.2968
# Train Epoch 0 Progress: 73.6%	Loss: 2.3159
# Train Epoch 0 Progress: 74.67%	Loss: 2.3117
# Train Epoch 0 Progress: 75.73%	Loss: 2.289
# Train Epoch 0 Progress: 76.8%	Loss: 2.3132
# Train Epoch 0 Progress: 77.87%	Loss: 2.3313
# Train Epoch 0 Progress: 78.93%	Loss: 2.2957
# Train Epoch 0 Progress: 80.0%	Loss: 2.3084
# Train Epoch 0 Progress: 81.07%	Loss: 2.3035
# Train Epoch 0 Progress: 82.13%	Loss: 2.3125
# Train Epoch 0 Progress: 83.2%	Loss: 2.3284
# Train Epoch 0 Progress: 84.27%	Loss: 2.3069
# Train Epoch 0 Progress: 85.33%	Loss: 2.2836
# Train Epoch 0 Progress: 86.4%	Loss: 2.3074
# Train Epoch 0 Progress: 87.47%	Loss: 2.304
# Train Epoch 0 Progress: 88.53%	Loss: 2.3194
# Train Epoch 0 Progress: 89.6%	Loss: 2.3066
# Train Epoch 0 Progress: 90.67%	Loss: 2.3073
# Train Epoch 0 Progress: 91.73%	Loss: 2.3245
# Train Epoch 0 Progress: 92.8%	Loss: 2.2955
# Train Epoch 0 Progress: 93.87%	Loss: 2.3029
# Train Epoch 0 Progress: 94.93%	Loss: 2.2901
# Train Epoch 0 Progress: 96.0%	Loss: 2.3089
# Train Epoch 0 Progress: 97.07%	Loss: 2.3032
# Train Epoch 0 Progress: 98.13%	Loss: 2.2982
# Train Epoch 0 Progress: 99.2%	Loss: 2.3023
#
# Test set: Avg loss 2.303, Accuracy 11.35%
#
# Train Epoch 1 Progress: 0.0%	Loss: 2.2966
# Train Epoch 1 Progress: 1.07%	Loss: 2.2926
# Train Epoch 1 Progress: 2.13%	Loss: 2.2955
# Train Epoch 1 Progress: 3.2%	Loss: 2.3023
# Train Epoch 1 Progress: 4.27%	Loss: 2.316
# Train Epoch 1 Progress: 5.33%	Loss: 2.314
# Train Epoch 1 Progress: 6.4%	Loss: 2.3204
# Train Epoch 1 Progress: 7.47%	Loss: 2.2906
# Train Epoch 1 Progress: 8.53%	Loss: 2.304
# Train Epoch 1 Progress: 9.6%	Loss: 2.2937
# Train Epoch 1 Progress: 10.67%	Loss: 2.3179
# Train Epoch 1 Progress: 11.73%	Loss: 2.29
# Train Epoch 1 Progress: 12.8%	Loss: 2.2976
# Train Epoch 1 Progress: 13.87%	Loss: 2.2772
# Train Epoch 1 Progress: 14.93%	Loss: 2.3238
# Train Epoch 1 Progress: 16.0%	Loss: 2.2996
# Train Epoch 1 Progress: 17.07%	Loss: 2.316
# Train Epoch 1 Progress: 18.13%	Loss: 2.2769
# Train Epoch 1 Progress: 19.2%	Loss: 2.3006
# Train Epoch 1 Progress: 20.27%	Loss: 2.2916
# Train Epoch 1 Progress: 21.33%	Loss: 2.3119
# Train Epoch 1 Progress: 22.4%	Loss: 2.3061
# Train Epoch 1 Progress: 23.47%	Loss: 2.3113
# Train Epoch 1 Progress: 24.53%	Loss: 2.3044
# Train Epoch 1 Progress: 25.6%	Loss: 2.315
# Train Epoch 1 Progress: 26.67%	Loss: 2.3164
# Train Epoch 1 Progress: 27.73%	Loss: 2.3048
# Train Epoch 1 Progress: 28.8%	Loss: 2.2997
# Train Epoch 1 Progress: 29.87%	Loss: 2.3119
# Train Epoch 1 Progress: 30.93%	Loss: 2.3044
# Train Epoch 1 Progress: 32.0%	Loss: 2.3135
# Train Epoch 1 Progress: 33.07%	Loss: 2.31
# Train Epoch 1 Progress: 34.13%	Loss: 2.3012
# Train Epoch 1 Progress: 35.2%	Loss: 2.2896
# Train Epoch 1 Progress: 36.27%	Loss: 2.2893
# Train Epoch 1 Progress: 37.33%	Loss: 2.3242
# Train Epoch 1 Progress: 38.4%	Loss: 2.3113
# Train Epoch 1 Progress: 39.47%	Loss: 2.2973
# Train Epoch 1 Progress: 40.53%	Loss: 2.3011
# Train Epoch 1 Progress: 41.6%	Loss: 2.3134
# Train Epoch 1 Progress: 42.67%	Loss: 2.3032
# Train Epoch 1 Progress: 43.73%	Loss: 2.315
# Train Epoch 1 Progress: 44.8%	Loss: 2.3027
# Train Epoch 1 Progress: 45.87%	Loss: 2.3014
# Train Epoch 1 Progress: 46.93%	Loss: 2.3036
# Train Epoch 1 Progress: 48.0%	Loss: 2.3117
# Train Epoch 1 Progress: 49.07%	Loss: 2.2803
# Train Epoch 1 Progress: 50.13%	Loss: 2.3265
# Train Epoch 1 Progress: 51.2%	Loss: 2.3008
# Train Epoch 1 Progress: 52.27%	Loss: 2.3017
# Train Epoch 1 Progress: 53.33%	Loss: 2.3099
# Train Epoch 1 Progress: 54.4%	Loss: 2.3055
# Train Epoch 1 Progress: 55.47%	Loss: 2.304
# Train Epoch 1 Progress: 56.53%	Loss: 2.312
# Train Epoch 1 Progress: 57.6%	Loss: 2.2899
# Train Epoch 1 Progress: 58.67%	Loss: 2.3132
# Train Epoch 1 Progress: 59.73%	Loss: 2.3245
# Train Epoch 1 Progress: 60.8%	Loss: 2.3053
# Train Epoch 1 Progress: 61.87%	Loss: 2.2826
# Train Epoch 1 Progress: 62.93%	Loss: 2.2929
# Train Epoch 1 Progress: 64.0%	Loss: 2.2953
# Train Epoch 1 Progress: 65.07%	Loss: 2.2969
# Train Epoch 1 Progress: 66.13%	Loss: 2.3272
# Train Epoch 1 Progress: 67.2%	Loss: 2.2959
# Train Epoch 1 Progress: 68.27%	Loss: 2.3079
# Train Epoch 1 Progress: 69.33%	Loss: 2.311
# Train Epoch 1 Progress: 70.4%	Loss: 2.3059
# Train Epoch 1 Progress: 71.47%	Loss: 2.3052
# Train Epoch 1 Progress: 72.53%	Loss: 2.3148
# Train Epoch 1 Progress: 73.6%	Loss: 2.2981
# Train Epoch 1 Progress: 74.67%	Loss: 2.2826
# Train Epoch 1 Progress: 75.73%	Loss: 2.3161
# Train Epoch 1 Progress: 76.8%	Loss: 2.3051
# Train Epoch 1 Progress: 77.87%	Loss: 2.3137
# Train Epoch 1 Progress: 78.93%	Loss: 2.2951
# Train Epoch 1 Progress: 80.0%	Loss: 2.306
# Train Epoch 1 Progress: 81.07%	Loss: 2.3191
# Train Epoch 1 Progress: 82.13%	Loss: 2.3159
# Train Epoch 1 Progress: 83.2%	Loss: 2.2819
# Train Epoch 1 Progress: 84.27%	Loss: 2.3167
# Train Epoch 1 Progress: 85.33%	Loss: 2.31
# Train Epoch 1 Progress: 86.4%	Loss: 2.2962
# Train Epoch 1 Progress: 87.47%	Loss: 2.3245
# Train Epoch 1 Progress: 88.53%	Loss: 2.3184
# Train Epoch 1 Progress: 89.6%	Loss: 2.3121
# Train Epoch 1 Progress: 90.67%	Loss: 2.3014
# Train Epoch 1 Progress: 91.73%	Loss: 2.3329
# Train Epoch 1 Progress: 92.8%	Loss: 2.2897
# Train Epoch 1 Progress: 93.87%	Loss: 2.3138
# Train Epoch 1 Progress: 94.93%	Loss: 2.3045
# Train Epoch 1 Progress: 96.0%	Loss: 2.3171
# Train Epoch 1 Progress: 97.07%	Loss: 2.2955
# Train Epoch 1 Progress: 98.13%	Loss: 2.3005
# Train Epoch 1 Progress: 99.2%	Loss: 2.2961
#
# Test set: Avg loss 2.305, Accuracy 11.35%
#
# Training with lr=0.1, momentum=0.9, batch_size=128
#
# Test set: Avg loss 2.3078, Accuracy 13.2%
#
# Train Epoch 0 Progress: 0.0%	Loss: 2.3397
# Train Epoch 0 Progress: 2.13%	Loss: 1.8226
# Train Epoch 0 Progress: 4.27%	Loss: 1.316
# Train Epoch 0 Progress: 6.4%	Loss: 1.0416
# Train Epoch 0 Progress: 8.53%	Loss: 0.9574
# Train Epoch 0 Progress: 10.67%	Loss: 1.1886
# Train Epoch 0 Progress: 12.8%	Loss: 0.8526
# Train Epoch 0 Progress: 14.93%	Loss: 1.2069
# Train Epoch 0 Progress: 17.07%	Loss: 0.9567
# Train Epoch 0 Progress: 19.2%	Loss: 0.914
# Train Epoch 0 Progress: 21.33%	Loss: 0.7393
# Train Epoch 0 Progress: 23.47%	Loss: 1.0989
# Train Epoch 0 Progress: 25.6%	Loss: 0.6872
# Train Epoch 0 Progress: 27.73%	Loss: 0.8658
# Train Epoch 0 Progress: 29.87%	Loss: 1.0251
# Train Epoch 0 Progress: 32.0%	Loss: 0.6796
# Train Epoch 0 Progress: 34.13%	Loss: 0.93
# Train Epoch 0 Progress: 36.27%	Loss: 0.845
# Train Epoch 0 Progress: 38.4%	Loss: 0.6959
# Train Epoch 0 Progress: 40.53%	Loss: 0.6918
# Train Epoch 0 Progress: 42.67%	Loss: 0.8189
# Train Epoch 0 Progress: 44.8%	Loss: 0.6768
# Train Epoch 0 Progress: 46.93%	Loss: 0.9274
# Train Epoch 0 Progress: 49.07%	Loss: 0.6796
# Train Epoch 0 Progress: 51.2%	Loss: 0.3559
# Train Epoch 0 Progress: 53.33%	Loss: 0.4992
# Train Epoch 0 Progress: 55.47%	Loss: 0.5932
# Train Epoch 0 Progress: 57.6%	Loss: 0.7796
# Train Epoch 0 Progress: 59.73%	Loss: 0.922
# Train Epoch 0 Progress: 61.87%	Loss: 0.5502
# Train Epoch 0 Progress: 64.0%	Loss: 0.635
# Train Epoch 0 Progress: 66.13%	Loss: 0.7011
# Train Epoch 0 Progress: 68.27%	Loss: 0.8702
# Train Epoch 0 Progress: 70.4%	Loss: 0.8259
# Train Epoch 0 Progress: 72.53%	Loss: 0.4952
# Train Epoch 0 Progress: 74.67%	Loss: 0.6452
# Train Epoch 0 Progress: 76.8%	Loss: 0.4348
# Train Epoch 0 Progress: 78.93%	Loss: 0.8384
# Train Epoch 0 Progress: 81.07%	Loss: 0.4923
# Train Epoch 0 Progress: 83.2%	Loss: 0.9202
# Train Epoch 0 Progress: 85.33%	Loss: 0.6257
# Train Epoch 0 Progress: 87.47%	Loss: 0.8715
# Train Epoch 0 Progress: 89.6%	Loss: 0.5318
# Train Epoch 0 Progress: 91.73%	Loss: 0.6054
# Train Epoch 0 Progress: 93.87%	Loss: 0.6164
# Train Epoch 0 Progress: 96.0%	Loss: 0.7225
# Train Epoch 0 Progress: 98.13%	Loss: 0.5769
#
# Test set: Avg loss 0.2493, Accuracy 92.57%
#
# Train Epoch 1 Progress: 0.0%	Loss: 0.7995
# Train Epoch 1 Progress: 2.13%	Loss: 0.6531
# Train Epoch 1 Progress: 4.27%	Loss: 0.4202
# Train Epoch 1 Progress: 6.4%	Loss: 0.5488
# Train Epoch 1 Progress: 8.53%	Loss: 0.6053
# Train Epoch 1 Progress: 10.67%	Loss: 0.9923
# Train Epoch 1 Progress: 12.8%	Loss: 0.7378
# Train Epoch 1 Progress: 14.93%	Loss: 0.5907
# Train Epoch 1 Progress: 17.07%	Loss: 0.6115
# Train Epoch 1 Progress: 19.2%	Loss: 0.7695
# Train Epoch 1 Progress: 21.33%	Loss: 0.479
# Train Epoch 1 Progress: 23.47%	Loss: 0.6764
# Train Epoch 1 Progress: 25.6%	Loss: 0.553
# Train Epoch 1 Progress: 27.73%	Loss: 0.5296
# Train Epoch 1 Progress: 29.87%	Loss: 1.0595
# Train Epoch 1 Progress: 32.0%	Loss: 0.7223
# Train Epoch 1 Progress: 34.13%	Loss: 0.6275
# Train Epoch 1 Progress: 36.27%	Loss: 0.6745
# Train Epoch 1 Progress: 38.4%	Loss: 0.4398
# Train Epoch 1 Progress: 40.53%	Loss: 0.4346
# Train Epoch 1 Progress: 42.67%	Loss: 0.8009
# Train Epoch 1 Progress: 44.8%	Loss: 0.7741
# Train Epoch 1 Progress: 46.93%	Loss: 0.5274
# Train Epoch 1 Progress: 49.07%	Loss: 0.5002
# Train Epoch 1 Progress: 51.2%	Loss: 0.3749
# Train Epoch 1 Progress: 53.33%	Loss: 0.433
# Train Epoch 1 Progress: 55.47%	Loss: 0.7347
# Train Epoch 1 Progress: 57.6%	Loss: 0.4525
# Train Epoch 1 Progress: 59.73%	Loss: 0.3518
# Train Epoch 1 Progress: 61.87%	Loss: 0.5451
# Train Epoch 1 Progress: 64.0%	Loss: 0.7237
# Train Epoch 1 Progress: 66.13%	Loss: 0.4498
# Train Epoch 1 Progress: 68.27%	Loss: 0.6834
# Train Epoch 1 Progress: 70.4%	Loss: 0.6304
# Train Epoch 1 Progress: 72.53%	Loss: 0.6474
# Train Epoch 1 Progress: 74.67%	Loss: 0.4725
# Train Epoch 1 Progress: 76.8%	Loss: 0.8561
# Train Epoch 1 Progress: 78.93%	Loss: 0.4464
# Train Epoch 1 Progress: 81.07%	Loss: 0.8809
# Train Epoch 1 Progress: 83.2%	Loss: 0.8403
# Train Epoch 1 Progress: 85.33%	Loss: 0.9674
# Train Epoch 1 Progress: 87.47%	Loss: 0.8419
# Train Epoch 1 Progress: 89.6%	Loss: 0.6093
# Train Epoch 1 Progress: 91.73%	Loss: 0.5679
# Train Epoch 1 Progress: 93.87%	Loss: 0.6517
# Train Epoch 1 Progress: 96.0%	Loss: 0.8569
# Train Epoch 1 Progress: 98.13%	Loss: 0.7081
#
# Test set: Avg loss 0.2025, Accuracy 94.25%

# %%
# Print the results sorted by accuracy
sorted_results = sorted(results, key=lambda x: x["test_accuracy"], reverse=True)
for result in sorted_results:
    print(result)
# Out:
# {'lr': 0.1, 'momentum': 0.5, 'batch_size': 64, 'test_loss': 0.062206532287597656, 'test_accuracy': 98.14}
# {'lr': 0.01, 'momentum': 0.9, 'batch_size': 32, 'test_loss': 0.06307551746368409, 'test_accuracy': 98.02}
# {'lr': 0.1, 'momentum': 0.5, 'batch_size': 128, 'test_loss': 0.0641890284538269, 'test_accuracy': 97.98}
# {'lr': 0.01, 'momentum': 0.9, 'batch_size': 64, 'test_loss': 0.07531947956085205, 'test_accuracy': 97.79}
# {'lr': 0.01, 'momentum': 0.9, 'batch_size': 128, 'test_loss': 0.07889421672821045, 'test_accuracy': 97.45}
# {'lr': 0.01, 'momentum': 0.5, 'batch_size': 32, 'test_loss': 0.09191143627166748, 'test_accuracy': 97.04}
# {'lr': 0.1, 'momentum': 0.5, 'batch_size': 32, 'test_loss': 0.11144698600769043, 'test_accuracy': 96.96}
# {'lr': 0.001, 'momentum': 0.9, 'batch_size': 32, 'test_loss': 0.11015312843322754, 'test_accuracy': 96.54}
# {'lr': 0.01, 'momentum': 0.5, 'batch_size': 64, 'test_loss': 0.12030541076660156, 'test_accuracy': 96.32}
# {'lr': 0.01, 'momentum': 0.5, 'batch_size': 128, 'test_loss': 0.19010227508544922, 'test_accuracy': 94.55}
# {'lr': 0.001, 'momentum': 0.9, 'batch_size': 64, 'test_loss': 0.18856714935302735, 'test_accuracy': 94.32}
# {'lr': 0.1, 'momentum': 0.9, 'batch_size': 128, 'test_loss': 0.2025372589111328, 'test_accuracy': 94.25}
# {'lr': 0.001, 'momentum': 0.9, 'batch_size': 128, 'test_loss': 0.2907896942138672, 'test_accuracy': 91.88}
# {'lr': 0.001, 'momentum': 0.5, 'batch_size': 32, 'test_loss': 0.40511569519042967, 'test_accuracy': 89.58}
# {'lr': 0.001, 'momentum': 0.5, 'batch_size': 64, 'test_loss': 0.6125198944091796, 'test_accuracy': 85.29}
# {'lr': 0.001, 'momentum': 0.5, 'batch_size': 128, 'test_loss': 2.153490380859375, 'test_accuracy': 45.5}
# {'lr': 0.1, 'momentum': 0.9, 'batch_size': 64, 'test_loss': 2.305008544921875, 'test_accuracy': 11.35}
# {'lr': 0.1, 'momentum': 0.9, 'batch_size': 32, 'test_loss': 2.3090807861328124, 'test_accuracy': 10.1}

# %% [markdown]
# ## Insight into Saving Models
# A common way to save a model is to serialize the internal state dictionary (containing the model parameters).

# %%
torch.save(conv_network.state_dict(), "model.pth")
print("Saved PyTorch Model State to model.pth")
# Out:
# Saved PyTorch Model State to model.pth

# %% [markdown]
# ## Insight into Loading Models
#
# The process for loading a model includes re-creating the model structure and loading
# the state dictionary into it.

# %%
model = ConvNet()
model.load_state_dict(torch.load("model.pth"))
# Out:
# <All keys matched successfully>

# %% [markdown]
# This model can now be used to make predictions.

# %%
# Download test data from open datasets.
test_data = datasets.MNIST('sample_data/',
    train=False,
    download=True,
    transform=transforms.ToTensor(),
)

classes = [1, 2, 3, 4, 5, 6, 7, 8, 9]

model.eval()
x, y = test_data[0][0], test_data[0][1]
with torch.no_grad():
    pred = model(x)
    predicted, actual = classes[pred[0].argmax(0)], classes[y]
    print(f'Predicted: "{predicted}", Actual: "{actual}"')
# Out:
# Predicted: "2", Actual: "8"
